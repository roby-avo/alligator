# %%
import requests

url = 'https://alligator.hel.sintef.cloud/dataset/test/table'
token = 'alligator_demo_2023'

files = {'file': ('film.csv', open('film.csv', 'rb'), 'text/csv')}
headers = {'accept': 'application/json'}
params = {'token': token}

response = requests.post(url, files=files, headers=headers, params=params)

print(response.status_code)
print(response.json())  # If the response is in JSON format
# Out:
# 200
# {'status': 'Ok', 'tables': [{'id': '64e35aa851c2716f1998144b', 'datasetName': 'test', 'tableName': 'film'}]}

# %%
import requests

url = 'https://alligator.hel.sintef.cloud/dataset/test/table/film'
token = 'alligator_demo_2023'

params = {'page': 1, 'token': token}
headers = {'accept': 'application/json'}

response = requests.get(url, headers=headers, params=params)


print(response.status_code)
print(response.json())  # If the response is in JSON format
result = response.json()
# Out:
# 200
# {'datasetName': 'test', 'tableName': 'film', 'rows': [{'idRow': 1, 'data': ['Avengers: Endgame', 'Anthony Russo', 2019, 'Walt Disney', 181, '356,000,000', '2,797,800,564', 8.5]}, {'idRow': 2, 'data': ['Joker', 'Todd Phillips', 2019, 'Warner Bros.', 122, '55,000,000', '1,071,030,470', 8.6]}, {'idRow': 3, 'data': ['Aquaman', 'James Wan', 2018, 'Warner Bros.', 143, '160,000,000', '1,148,161,807', 7.0]}, {'idRow': 4, 'data': ['Venom', 'Ruben Fleischer', 2018, 'Sony Pictures', 112, '100,000,000', '856,085,151', 6.7]}, {'idRow': 5, 'data': ['Wonder Woman', 'Patty Jenkins', 2017, 'Walt Disney', 130, '180,000,000', '853,977,126', 7.9]}, {'idRow': 6, 'data': ['Thor: Ragnarok', 'Taika Waititi', 2017, 'Warner Bros.', 141, '149,000,000', '821,847,012', 7.4]}, {'idRow': 7, 'data': ['Jurassic World', 'Colin Trevorrow', 2015, 'Universal Pictures', 124, '150,000,000', '1,670,400,637', 7.0]}, {'idRow': 8, 'data': ['Inside Out', 'Pete Docter ', 2015, 'Walt Disney', 95, '175,000,000', '857,611,174', 8.2]}, {'idRow': 9, 'data': ['Maleficent', 'Robert Stromberg', 2014, 'Walt Disney', 97, '180,000,000', '758,410,378', 7.0]}, {'idRow': 10, 'data': ['Captain America: The Winter Soldier', 'Anthony Russo', 2014, 'Walt Disney', 136, '170,000,000', '714,421,503', 7.7]}, {'idRow': 11, 'data': ['Iron Man 3', 'Shane Black', 2013, 'Walt Disney', 130, '200,000,000', '1,214,811,252', 7.2]}, {'idRow': 12, 'data': ['Gravity', 'Alfonso Cuaron', 2013, 'Warner Bros.', 91, '100,000,000', '723,192,705', 7.7]}, {'idRow': 13, 'data': ['Superman Returns', 'Bryan Singer', 2006, 'Warner Bros.', 154, '270,000,000', '391,081,192', 6.0]}, {'idRow': 14, 'data': ['Batman Begins', 'Christopher Nolan', 2005, 'Warner Bros.', 140, '150,000,000', '371,853,783', 8.2]}, {'idRow': 15, 'data': ['Harry Potter and the Prisoner of Azkaban', 'Alfonso Cuarón', 2004, 'Warner Bros.', 142, '130,000,000', '795,634,069', 7.9]}, {'idRow': 16, 'data': ['The Matrix Reloaded', 'Andy Wachowski', 2003, 'Warner Bros.', 138, '150,000,000', '739,412,035', 7.2]}, {'idRow': 17, 'data': ['Avatar', 'James Cameron', 2009, 'Twentieth Century Fox', 162, '237,000,000', '2,744,336,793', 7.8]}], 'semanticAnnotations': {'cea': [{'idColumn': 0, 'idRow': 1, 'entity': [{'id': 'Q23781155', 'name': 'avengers: endgame', 'type': [{'id': 'Q11424', 'name': 'film'}], 'description': '2019 film directed by anthony and joe russo', 'match': True, 'score': 0.706}]}, {'idColumn': 1, 'idRow': 1, 'entity': [{'id': 'Q18018415', 'name': 'anthony russo', 'type': [{'id': 'Q2526255', 'name': 'film director'}, {'id': 'Q2059704', 'name': 'television director'}, {'id': 'Q28389', 'name': 'screenwriter'}, {'id': 'Q3455803', 'name': 'director'}, {'id': 'Q69423232', 'name': 'film screenwriter'}, {'id': 'Q1607826', 'name': 'editor'}, {'id': 'Q3282637', 'name': 'film producer'}, {'id': 'Q115088092', 'name': 'international forum participant'}, {'id': 'Q5', 'name': 'human'}], 'description': 'american film director, television director and screenwriter', 'match': True, 'score': 0.831}]}, {'idColumn': 2, 'idRow': 1, 'entity': []}, {'idColumn': 3, 'idRow': 1, 'entity': [{'id': 'Q1047410', 'name': 'walt disney animation studios', 'type': [{'id': 'Q1107679', 'name': 'animation studio'}, {'id': 'Q1762059', 'name': 'film production company'}], 'description': 'walt disney company animation studio', 'match': True, 'score': 0.822}]}, {'idColumn': 4, 'idRow': 1, 'entity': []}, {'idColumn': 5, 'idRow': 1, 'entity': []}, {'idColumn': 6, 'idRow': 1, 'entity': []}, {'idColumn': 7, 'idRow': 1, 'entity': []}, {'idColumn': 0, 'idRow': 2, 'entity': [{'id': 'Q42759035', 'name': 'joker', 'type': [{'id': 'Q11424', 'name': 'film'}], 'description': '2019 film directed by todd phillips', 'match': False, 'score': 0.059}, {'id': 'Q78988947', 'name': 'joker', 'type': [{'id': 'Q1002697', 'name': 'periodical'}], 'description': 'periodical', 'match': False, 'score': 0.042}, {'id': 'Q83586746', 'name': 'joker', 'type': [{'id': 'Q11446', 'name': 'ship'}], 'description': 'ship buil ...

# %%
import pandas as pd

def get_dict_cea_data(cea):
    entities = {}
    for item in cea:
        id_row, id_col = (item["idRow"], item["idColumn"])
        if len(item["entity"]) > 0:
            entities[f"{id_row} {id_col}"] = item["entity"][0]
    return entities   


headers = []
rows = []
i = 0
entities = get_dict_cea_data(result["semanticAnnotations"]["cea"])
for row in result["rows"]:
    cells = []
    id_row = row["idRow"]
    for id_col, cell in enumerate(row["data"]):
        cells.append(cell)
        entity = entities.get(f"{id_row} {id_col}")
        if entity is not None:
            cells.append(entity["id"])
            cells.append(entity["name"])
            cells.append(entity["score"])
        i+=1
    rows.append(cells)    

#pd.DataFrame([item["data"] for item in ["rows"]])

# %%
pd.DataFrame(rows)

# %%
result["semanticAnnotations"]["cea"]
# Out:
# [{'idColumn': 0,
#   'idRow': 1,
#   'entity': [{'id': 'Q23781155',
#     'name': 'avengers: endgame',
#     'type': [{'id': 'Q11424', 'name': 'film'}],
#     'description': '2019 film directed by anthony and joe russo',
#     'match': True,
#     'score': 0.706}]},
#  {'idColumn': 1,
#   'idRow': 1,
#   'entity': [{'id': 'Q18018415',
#     'name': 'anthony russo',
#     'type': [{'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q2059704', 'name': 'television director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3455803', 'name': 'director'},
#      {'id': 'Q69423232', 'name': 'film screenwriter'},
#      {'id': 'Q1607826', 'name': 'editor'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q115088092', 'name': 'international forum participant'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'american film director, television director and screenwriter',
#     'match': True,
#     'score': 0.831}]},
#  {'idColumn': 2, 'idRow': 1, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 1,
#   'entity': [{'id': 'Q1047410',
#     'name': 'walt disney animation studios',
#     'type': [{'id': 'Q1107679', 'name': 'animation studio'},
#      {'id': 'Q1762059', 'name': 'film production company'}],
#     'description': 'walt disney company animation studio',
#     'match': True,
#     'score': 0.822}]},
#  {'idColumn': 4, 'idRow': 1, 'entity': []},
#  {'idColumn': 5, 'idRow': 1, 'entity': []},
#  {'idColumn': 6, 'idRow': 1, 'entity': []},
#  {'idColumn': 7, 'idRow': 1, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 2,
#   'entity': [{'id': 'Q42759035',
#     'name': 'joker',
#     'type': [{'id': 'Q11424', 'name': 'film'}],
#     'description': '2019 film directed by todd phillips',
#     'match': False,
#     'score': 0.059},
#    {'id': 'Q78988947',
#     'name': 'joker',
#     'type': [{'id': 'Q1002697', 'name': 'periodical'}],
#     'description': 'periodical',
#     'match': False,
#     'score': 0.042},
#    {'id': 'Q83586746',
#     'name': 'joker',
#     'type': [{'id': 'Q11446', 'name': 'ship'}],
#     'description': 'ship built by peters werft',
#     'match': False,
#     'score': 0.033}]},
#  {'idColumn': 1,
#   'idRow': 2,
#   'entity': [{'id': 'Q102358498',
#     'name': 'todd phillips',
#     'type': [{'id': 'Q5', 'name': 'human'}],
#     'description': 'ph.d. carnegie mellon university 2009',
#     'match': False,
#     'score': 0.168},
#    {'id': 'Q362824',
#     'name': 'todd phillips',
#     'type': [{'id': 'Q5', 'name': 'human'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q36180', 'name': 'writer'},
#      {'id': 'Q33999', 'name': 'actor'},
#      {'id': 'Q10800557', 'name': 'film actor'}],
#     'description': 'american filmmaker',
#     'match': False,
#     'score': 0.23},
#    {'id': 'Q118220019',
#     'name': 'todd phillips',
#     'type': [{'id': 'Q5', 'name': 'human'}],
#     'description': 'american basketball player and coach',
#     'match': False,
#     'score': 0.217}]},
#  {'idColumn': 2, 'idRow': 2, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 2,
#   'entity': [{'id': 'Q126399',
#     'name': 'warner bros.',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q20739124', 'name': 'entertainment company'}],
#     'description': 'american entertainment company',
#     'match': True,
#     'score': 0.991}]},
#  {'idColumn': 4, 'idRow': 2, 'entity': []},
#  {'idColumn': 5, 'idRow': 2, 'entity': []},
#  {'idColumn': 6, 'idRow': 2, 'entity': []},
#  {'idColumn': 7, 'idRow': 2, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 3,
#   'entity': [{'id': 'Q117102059',
#     'name': 'aquaman',
#     'type': [{'id': 'Q191826', 'name': 'tug'}],
#     'description': 'tug boat built in 2003',
#     'match': False,
#     'score': 0.014},
#    {'id': 'Q60839030',
#     'name': 'aquaman',
#     'type': [{'id': 'Q1004', 'name': 'comics'}],
#     'description': '',
#     'match': False,
#     'score': 0.018},
#    {'id': 'Q22998395',
#     'name': 'aquaman',
#     'type': [{'id': 'Q229390', 'name': '3D film'},
#      {'id': 'Q11424', 'name': 'film'}],
#     'description': '2018 film directed by james wan',
#     'match': False,
#     'score': 0.023}]},
#  {'idColumn': 1,
#   'idRow': 3,
#   'entity': [{'id': 'Q108047434',
#     'name': 'james wan',
#     'type': [{'id': 'Q5', 'name': 'human'},
#      {'id': 'Q7042855', 'name': 'film editor'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q36180', 'name': 'writer'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q1053574', 'name': 'executive producer'},
#      {'id': 'Q69423232', 'name': 'film screenwriter'}],
#     'description': 'malaysian-australian director, producer, screenwriter, and comic book writer',
#     'match': True,
#     'score': 0.585}]},
#  {'idColumn': 2, 'idRow': 3, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 3,
#   'entity': [{'id': 'Q126399',
#     'name': 'warner bros.',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q20739124', 'name': 'entertainment company'}],
#     'description': 'american entertainment company',
#     'match': True,
#     'score': 0.991}]},
#  {'idColumn': 4, 'idRow': 3, 'entity': []},
#  {'idColumn': 5, 'idRow': 3, 'entity': []},
#  {'idColumn': 6, 'idRow': 3, 'entity': []},
#  {'idColumn': 7, 'idRow': 3, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 4,
#   'entity': [{'id': 'Q40867',
#     'name': 'venom',
#     'type': [{'id': 'Q100434640',
#       'name': 'class of chemical substances by use'},
#      {'id': 'Q1931388', 'name': 'cause of death'}],
#     'description': 'substance that causes death, injury or harm to organs, when an organism absorbs a sufficient quantity',
#     'match': False,
#     'score': 0.044},
#    {'id': 'Q60498064',
#     'name': 'venom 2',
#     'type': [{'id': 'Q11424', 'name': 'film'}],
#     'description': '2021 film directed by andy serkis',
#     'match': False,
#     'score': 0.044},
#    {'id': 'Q3386847',
#     'name': 'venom',
#     'type': [{'id': '', 'name': ''}],
#     'description': 'mixture of toxins and other substances secreted by an animal for the purpose of causing harm to another',
#     'match': False,
#     'score': 0.027}]},
#  {'idColumn': 1,
#   'idRow': 4,
#   'entity': [{'id': 'Q521691',
#     'name': 'ruben fleischer',
#     'type': [{'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'american film director',
#     'match': True,
#     'score': 0.96}]},
#  {'idColumn': 2, 'idRow': 4, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 4,
#   'entity': [{'id': 'Q822314',
#     'name': 'sony pictures',
#     'type': [{'id': 'Q658255', 'name': 'subsidiary'},
#      {'id': 'Q1762059', 'name': 'film production company'}],
#     'description': 'american television and film production and distribution unit of sony',
#     'match': True,
#     'score': 0.96}]},
#  {'idColumn': 4, 'idRow': 4, 'entity': []},
#  {'idColumn': 5, 'idRow': 4, 'entity': []},
#  {'idColumn': 6, 'idRow': 4, 'entity': []},
#  {'idColumn': 7, 'idRow': 4, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 5,
#   'entity': [{'id': 'Q52157964',
#     'name': 'wonder woman',
#     'type': [{'id': 'Q1114461', 'name': 'comics character'},
#      {'id': 'Q2805205', 'name': 'Amazons'},
#      {'id': 'Q188784', 'name': 'superhero'},
#      {'id': 'Q11124885', 'name': 'martial artist'}],
#     'description': 'fictional character, kingom come version of wonder woman in the dc comics universe',
#     'match': False,
#     'score': 0.475}]},
#  {'idColumn': 1,
#   'idRow': 5,
#   'entity': [{'id': 'Q456910',
#     'name': 'patty jenkins',
#     'type': [{'id': 'Q5', 'name': 'human'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q36180', 'name': 'writer'},
#      {'id': 'Q2059704', 'name': 'television director'},
#      {'id': 'Q3455803', 'name': 'director'}],
#     'description': 'american filmmaker',
#     'match': True,
#     'score': 0.963}]},
#  {'idColumn': 2, 'idRow': 5, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 5,
#   'entity': [{'id': 'Q1047410',
#     'name': 'walt disney animation studios',
#     'type': [{'id': 'Q1107679', 'name': 'animation studio'},
#      {'id': 'Q1762059', 'name': 'film production company'}],
#     'description': 'walt disney company animation studio',
#     'match': True,
#     'score': 0.821}]},
#  {'idColumn': 4, 'idRow': 5, 'entity': []},
#  {'idColumn': 5, 'idRow': 5, 'entity': []},
#  {'idColumn': 6, 'idRow': 5, 'entity': []},
#  {'idColumn': 7, 'idRow': 5, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 6,
#   'entity': [{'id': 'Q22665878',
#     'name': 'thor: ragnarok',
#     'type': [{'id': 'Q11424', 'name': 'film'},
#      {'id': 'Q261636', 'name': 'sequel'}],
#     'description': '2017 film directed by taika waititi',
#     'match': False,
#     'score': 0.086}]},
#  {'idColumn': 1,
#   'idRow': 6,
#   'entity': [{'id': 'Q2388576',
#     'name': 'taika waititi',
#     'type': [{'id': 'Q33999', 'name': 'actor'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3455803', 'name': 'director'},
#      {'id': 'Q1053574', 'name': 'executive producer'},
#      {'id': 'Q10800557', 'name': 'film actor'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q245068', 'name': 'comedian'},
#      {'id': 'Q2405480', 'name': 'voice actor'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'new zealand filmmaker, actor, and comedian',
#     'match': True,
#     'score': 0.953}]},
#  {'idColumn': 2, 'idRow': 6, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 6,
#   'entity': [{'id': 'Q126399',
#     'name': 'warner bros.',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q20739124', 'name': 'entertainment company'}],
#     'description': 'american entertainment company',
#     'match': True,
#     'score': 0.93}]},
#  {'idColumn': 4, 'idRow': 6, 'entity': []},
#  {'idColumn': 5, 'idRow': 6, 'entity': []},
#  {'idColumn': 6, 'idRow': 6, 'entity': []},
#  {'idColumn': 7, 'idRow': 6, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 7,
#   'entity': [{'id': 'Q55615459',
#     'name': 'jurassic world',
#     'type': [{'id': 'Q1144661', 'name': 'amusement ride'}],
#     'description': 'a ride themed to the jurassic world series at universal studios hollywood',
#     'match': True,
#     'score': 0.799}]},
#  {'idColumn': 1,
#   'idRow': 7,
#   'entity': [{'id': 'Q5145625',
#     'name': 'colin trevorrow',
#     'type': [{'id': 'Q5', 'name': 'human'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3455803', 'name': 'director'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q33999', 'name': 'actor'}],
#     'description': 'american film director',
#     'match': True,
#     'score': 0.977}]},
#  {'idColumn': 2, 'idRow': 7, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 7,
#   'entity': [{'id': 'Q168383',
#     'name': 'universal pictures',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q375336', 'name': 'film studio'},
#      {'id': 'Q43229', 'name': 'organization'}],
#     'description': 'american film studio',
#     'match': True,
#     'score': 0.593}]},
#  {'idColumn': 4, 'idRow': 7, 'entity': []},
#  {'idColumn': 5, 'idRow': 7, 'entity': []},
#  {'idColumn': 6, 'idRow': 7, 'entity': []},
#  {'idColumn': 7, 'idRow': 7, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 8,
#   'entity': [{'id': 'Q114535928',
#     'name': 'inside out',
#     'type': [{'id': 'Q21191270', 'name': 'television series episode'}],
#     'description': 'episode of the unit',
#     'match': False,
#     'score': 0.243}]},
#  {'idColumn': 1,
#   'idRow': 8,
#   'entity': [{'id': 'Q357627',
#     'name': 'pete docter',
#     'type': [{'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q266569', 'name': 'animator'},
#      {'id': 'Q2405480', 'name': 'voice actor'},
#      {'id': 'Q1053574', 'name': 'executive producer'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'american animator and film director',
#     'match': True,
#     'score': 0.857}]},
#  {'idColumn': 2, 'idRow': 8, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 8,
#   'entity': [{'id': 'Q1047410',
#     'name': 'walt disney animation studios',
#     'type': [{'id': 'Q1107679', 'name': 'animation studio'},
#      {'id': 'Q1762059', 'name': 'film production company'}],
#     'description': 'walt disney company animation studio',
#     'match': True,
#     'score': 0.821}]},
#  {'idColumn': 4, 'idRow': 8, 'entity': []},
#  {'idColumn': 5, 'idRow': 8, 'entity': []},
#  {'idColumn': 6, 'idRow': 8, 'entity': []},
#  {'idColumn': 7, 'idRow': 8, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 9,
#   'entity': [{'id': 'Q19728757',
#     'name': 'maleficent',
#     'type': [{'id': 'Q95074', 'name': 'fictional character'}],
#     'description': 'titular character from the 2014 disney film "maleficent" played by angelina jolie',
#     'match': False,
#     'score': 0.393}]},
#  {'idColumn': 1,
#   'idRow': 9,
#   'entity': [{'id': 'Q2158922',
#     'name': 'robert stromberg',
#     'type': [{'id': 'Q5', 'name': 'human'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q5322166', 'name': 'designer'}],
#     'description': 'american film art director',
#     'match': True,
#     'score': 0.96}]},
#  {'idColumn': 2, 'idRow': 9, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 9,
#   'entity': [{'id': 'Q1047410',
#     'name': 'walt disney animation studios',
#     'type': [{'id': 'Q1107679', 'name': 'animation studio'},
#      {'id': 'Q1762059', 'name': 'film production company'}],
#     'description': 'walt disney company animation studio',
#     'match': True,
#     'score': 0.821}]},
#  {'idColumn': 4, 'idRow': 9, 'entity': []},
#  {'idColumn': 5, 'idRow': 9, 'entity': []},
#  {'idColumn': 6, 'idRow': 9, 'entity': []},
#  {'idColumn': 7, 'idRow': 9, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 10,
#   'entity': [{'id': 'Q16155418',
#     'name': 'captain america: the winter soldier',
#     'type': [{'id': 'Q482994', 'name': 'album'}],
#     'description': 'soundtrack of the 2014 superhero film',
#     'match': False,
#     'score': 0.153},
#    {'id': 'Q1765358',
#     'name': 'captain america: the winter soldier',
#     'type': [{'id': 'Q229390', 'name': '3D film'},
#      {'id': 'Q11424', 'name': 'film'}],
#     'description': '2014 film directed by anthony russo and joe russo',
#     'match': False,
#     'score': 0.285}]},
#  {'idColumn': 1,
#   'idRow': 10,
#   'entity': [{'id': 'Q18018415',
#     'name': 'anthony russo',
#     'type': [{'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q2059704', 'name': 'television director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3455803', 'name': 'director'},
#      {'id': 'Q69423232', 'name': 'film screenwriter'},
#      {'id': 'Q1607826', 'name': 'editor'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q115088092', 'name': 'international forum participant'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'american film director, television director and screenwriter',
#     'match': True,
#     'score': 0.813}]},
#  {'idColumn': 2, 'idRow': 10, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 10,
#   'entity': [{'id': 'Q1047410',
#     'name': 'walt disney animation studios',
#     'type': [{'id': 'Q1107679', 'name': 'animation studio'},
#      {'id': 'Q1762059', 'name': 'film production company'}],
#     'description': 'walt disney company animation studio',
#     'match': True,
#     'score': 0.827}]},
#  {'idColumn': 4, 'idRow': 10, 'entity': []},
#  {'idColumn': 5, 'idRow': 10, 'entity': []},
#  {'idColumn': 6, 'idRow': 10, 'entity': []},
#  {'idColumn': 7, 'idRow': 10, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 11,
#   'entity': [{'id': 'Q11618777',
#     'name': 'iron man 3',
#     'type': [{'id': 'Q482994', 'name': 'album'}],
#     'description': '2013 soundtrack album',
#     'match': True,
#     'score': 0.829}]},
#  {'idColumn': 1,
#   'idRow': 11,
#   'entity': [{'id': 'Q726126',
#     'name': 'shane black',
#     'type': [{'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q33999', 'name': 'actor'},
#      {'id': 'Q10800557', 'name': 'film actor'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'american actor, screenwriter and film director',
#     'match': True,
#     'score': 0.84}]},
#  {'idColumn': 2, 'idRow': 11, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 11,
#   'entity': [{'id': 'Q1047410',
#     'name': 'walt disney animation studios',
#     'type': [{'id': 'Q1107679', 'name': 'animation studio'},
#      {'id': 'Q1762059', 'name': 'film production company'}],
#     'description': 'walt disney company animation studio',
#     'match': True,
#     'score': 0.821}]},
#  {'idColumn': 4, 'idRow': 11, 'entity': []},
#  {'idColumn': 5, 'idRow': 11, 'entity': []},
#  {'idColumn': 6, 'idRow': 11, 'entity': []},
#  {'idColumn': 7, 'idRow': 11, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 12,
#   'entity': [{'id': 'Q38635',
#     'name': 'gravity',
#     'type': [{'id': 'Q12812139', 'name': 'technical term'}],
#     'description': 'technical term; relative density compared to water, of the wort or must at various stages in the fermentation of alcoholic beverages',
#     'match': False,
#     'score': 0.368}]},
#  {'idColumn': 1,
#   'idRow': 12,
#   'entity': [{'id': 'Q28028',
#     'name': 'alfonso cuaron',
#     'type': [{'id': 'Q5', 'name': 'human'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q7042855', 'name': 'film editor'},
#      {'id': 'Q2059704', 'name': 'television director'},
#      {'id': 'Q222344', 'name': 'cinematographer'},
#      {'id': 'Q10798782', 'name': 'television actor'},
#      {'id': 'Q1414443', 'name': 'filmmaker'},
#      {'id': 'Q578109', 'name': 'television producer'}],
#     'description': 'mexican filmmaker',
#     'match': True,
#     'score': 0.773}]},
#  {'idColumn': 2, 'idRow': 12, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 12,
#   'entity': [{'id': 'Q126399',
#     'name': 'warner bros.',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q20739124', 'name': 'entertainment company'}],
#     'description': 'american entertainment company',
#     'match': True,
#     'score': 0.929}]},
#  {'idColumn': 4, 'idRow': 12, 'entity': []},
#  {'idColumn': 5, 'idRow': 12, 'entity': []},
#  {'idColumn': 6, 'idRow': 12, 'entity': []},
#  {'idColumn': 7, 'idRow': 12, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 13,
#   'entity': [{'id': 'Q3977963',
#     'name': 'superman returns',
#     'type': [{'id': 'Q482994', 'name': 'album'}],
#     'description': 'soundtrack album for the 2006 film of the same name',
#     'match': False,
#     'score': 0.237}]},
#  {'idColumn': 1,
#   'idRow': 13,
#   'entity': [{'id': 'Q220751',
#     'name': 'bryan singer',
#     'type': [{'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q33999', 'name': 'actor'},
#      {'id': 'Q578109', 'name': 'television producer'},
#      {'id': 'Q10800557', 'name': 'film actor'},
#      {'id': 'Q1053574', 'name': 'executive producer'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'american film director, writer and producer',
#     'match': False,
#     'score': 0.272},
#    {'id': 'Q102341364',
#     'name': 'bryan singer',
#     'type': [{'id': 'Q5', 'name': 'human'}],
#     'description': 'ph.d. carnegie mellon university 2001',
#     'match': False,
#     'score': 0.608}]},
#  {'idColumn': 2, 'idRow': 13, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 13,
#   'entity': [{'id': 'Q126399',
#     'name': 'warner bros.',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q20739124', 'name': 'entertainment company'}],
#     'description': 'american entertainment company',
#     'match': True,
#     'score': 0.991}]},
#  {'idColumn': 4, 'idRow': 13, 'entity': []},
#  {'idColumn': 5, 'idRow': 13, 'entity': []},
#  {'idColumn': 6, 'idRow': 13, 'entity': []},
#  {'idColumn': 7, 'idRow': 13, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 14,
#   'entity': [{'id': 'Q2401367',
#     'name': 'batman begins',
#     'type': [{'id': 'Q482994', 'name': 'album'}],
#     'description': '2005 soundtrack album by hans zimmer and james newton howard',
#     'match': False,
#     'score': 0.137},
#    {'id': 'Q166262',
#     'name': 'batman begins',
#     'type': [{'id': 'Q11424', 'name': 'film'},
#      {'id': 'Q111241092', 'name': 'film reboot'}],
#     'description': '2005 film by christopher nolan',
#     'match': False,
#     'score': 0.123}]},
#  {'idColumn': 1,
#   'idRow': 14,
#   'entity': [{'id': 'Q25191',
#     'name': 'christopher nolan',
#     'type': [{'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q33999', 'name': 'actor'},
#      {'id': 'Q36180', 'name': 'writer'},
#      {'id': 'Q1208175', 'name': 'camera operator'},
#      {'id': 'Q10800557', 'name': 'film actor'},
#      {'id': 'Q1053574', 'name': 'executive producer'},
#      {'id': 'Q7042855', 'name': 'film editor'},
#      {'id': 'Q222344', 'name': 'cinematographer'},
#      {'id': 'Q3455803', 'name': 'director'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'british–american filmmaker',
#     'match': True,
#     'score': 0.657}]},
#  {'idColumn': 2, 'idRow': 14, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 14,
#   'entity': [{'id': 'Q126399',
#     'name': 'warner bros.',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q20739124', 'name': 'entertainment company'}],
#     'description': 'american entertainment company',
#     'match': True,
#     'score': 0.991}]},
#  {'idColumn': 4, 'idRow': 14, 'entity': []},
#  {'idColumn': 5, 'idRow': 14, 'entity': []},
#  {'idColumn': 6, 'idRow': 14, 'entity': []},
#  {'idColumn': 7, 'idRow': 14, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 15,
#   'entity': [{'id': 'Q1148607',
#     'name': 'harry potter and the prisoner of azkaban',
#     'type': [{'id': 'Q482994', 'name': 'album'}],
#     'description': '2004 soundtrack album by john williams',
#     'match': False,
#     'score': 0.27}]},
#  {'idColumn': 1,
#   'idRow': 15,
#   'entity': [{'id': 'Q28028',
#     'name': 'alfonso cuarón',
#     'type': [{'id': 'Q5', 'name': 'human'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q7042855', 'name': 'film editor'},
#      {'id': 'Q2059704', 'name': 'television director'},
#      {'id': 'Q222344', 'name': 'cinematographer'},
#      {'id': 'Q10798782', 'name': 'television actor'},
#      {'id': 'Q1414443', 'name': 'filmmaker'},
#      {'id': 'Q578109', 'name': 'television producer'}],
#     'description': 'mexican filmmaker',
#     'match': True,
#     'score': 0.909}]},
#  {'idColumn': 2, 'idRow': 15, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 15,
#   'entity': [{'id': 'Q126399',
#     'name': 'warner bros.',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q20739124', 'name': 'entertainment company'}],
#     'description': 'american entertainment company',
#     'match': True,
#     'score': 0.991}]},
#  {'idColumn': 4, 'idRow': 15, 'entity': []},
#  {'idColumn': 5, 'idRow': 15, 'entity': []},
#  {'idColumn': 6, 'idRow': 15, 'entity': []},
#  {'idColumn': 7, 'idRow': 15, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 16,
#   'entity': [{'id': 'Q189600',
#     'name': 'the matrix reloaded',
#     'type': [{'id': 'Q11424', 'name': 'film'}],
#     'description': '2003 film by the wachowskis',
#     'match': True,
#     'score': 0.522}]},
#  {'idColumn': 1,
#   'idRow': 16,
#   'entity': [{'id': 'Q21500865',
#     'name': 'wachowski',
#     'type': [{'id': 'Q101352', 'name': 'family name'}],
#     'description': 'family name',
#     'match': False,
#     'score': 0.043}]},
#  {'idColumn': 2, 'idRow': 16, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 16,
#   'entity': [{'id': 'Q126399',
#     'name': 'warner bros.',
#     'type': [{'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q20739124', 'name': 'entertainment company'}],
#     'description': 'american entertainment company',
#     'match': True,
#     'score': 0.991}]},
#  {'idColumn': 4, 'idRow': 16, 'entity': []},
#  {'idColumn': 5, 'idRow': 16, 'entity': []},
#  {'idColumn': 6, 'idRow': 16, 'entity': []},
#  {'idColumn': 7, 'idRow': 16, 'entity': []},
#  {'idColumn': 0,
#   'idRow': 17,
#   'entity': [{'id': 'Q47465285',
#     'name': 'avatar',
#     'type': [{'id': 'Q11424', 'name': 'film'}],
#     'description': 'nepali film',
#     'match': False,
#     'score': 0.167}]},
#  {'idColumn': 1,
#   'idRow': 17,
#   'entity': [{'id': 'Q42574',
#     'name': 'james cameron',
#     'type': [{'id': 'Q3282637', 'name': 'film producer'},
#      {'id': 'Q2526255', 'name': 'film director'},
#      {'id': 'Q28389', 'name': 'screenwriter'},
#      {'id': 'Q7042855', 'name': 'film editor'},
#      {'id': 'Q205375', 'name': 'inventor'},
#      {'id': 'Q3455803', 'name': 'director'},
#      {'id': 'Q12362622', 'name': 'philanthropist'},
#      {'id': 'Q81096', 'name': 'engineer'},
#      {'id': 'Q33999', 'name': 'actor'},
#      {'id': 'Q11900058', 'name': 'explorer'},
#      {'id': 'Q578109', 'name': 'television producer'},
#      {'id': 'Q5', 'name': 'human'}],
#     'description': 'canadian filmmaker',
#     'match': True,
#     'score': 0.581}]},
#  {'idColumn': 2, 'idRow': 17, 'entity': []},
#  {'idColumn': 3,
#   'idRow': 17,
#   'entity': [{'id': 'Q434841',
#     'name': 'twentieth century fox',
#     'type': [{'id': 'Q375336', 'name': 'film studio'},
#      {'id': 'Q1762059', 'name': 'film production company'},
#      {'id': 'Q10689397', 'name': 'television production company'}],
#     'description': 'american film studio; subsidiary of walt disney studios',
#     'match': True,
#     'score': 0.772}]},
#  {'idColumn': 4, 'idRow': 17, 'entity': []},
#  {'idColumn': 5, 'idRow': 17, 'entity': []},
#  {'idColumn': 6, 'idRow': 17, 'entity': []},
#  {'idColumn': 7, 'idRow': 17, 'entity': []}]
