# %%
import os
import sys
import time
import traceback

import joblib
import redis
from keras.models import load_model

from phases.cea import CEAProcess
from phases.cpa import CPAProcess
from phases.cta import CTAProcess
from phases.data_preparation import compute_datatype, pre_processing
from phases.revision import RevisionProcess
from wrapper.lamAPI import LamAPI
from wrapper.logistic_regressor import LogisticRegressor
from wrapper.mongodb_conn import get_collection
from wrapper.neural_network import NeuralNetwork

neural1_path = "./ml_models/neural_network1.h5"
neural2_path = "./ml_models/neural_network2.h5"
logistic1_path = "./ml_models/logistic1.pkl"
logistic2_path = "./ml_models/logistic2.pkl"

rankers = [
                NeuralNetwork(load_model(neural1_path), "neural1"), 
                NeuralNetwork(load_model(neural2_path), "neural2"), 
                LogisticRegressor(joblib.load(logistic1_path), "logistic1"),
                LogisticRegressor(joblib.load(logistic2_path), "logistic2")
        ]


start = time.time()

REDIS_ENDPOINT = os.environ["REDIS_ENDPOINT"]
REDIS_JOB_DB = int(os.environ["REDIS_JOB_DB"])
LAMAPI_HOST, LAMAPI_PORT = os.environ["LAMAPI_ENDPOINT"].split(":")
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]

lamAPI = LamAPI(LAMAPI_HOST, LAMAPI_PORT, LAMAPI_TOKEN)
job_active = redis.Redis(host=REDIS_ENDPOINT, db=REDIS_JOB_DB)

row_c = get_collection('row')
log_c = get_collection('log')
cea_init_c = get_collection('ceaInit')
header_cea_c = get_collection('ceaHeader')
cea_c = get_collection('cea')
cpa_c = get_collection('cpa')
cta_c = get_collection('cta')
header_candidate_scored_c = get_collection('headerCandidateScored')
candidate_scored_c = get_collection('candidateScored')
data = row_c.find_one({})


if data is None:
    job_active.set("STOP", "")
    sys.exit(0)

header = data.get("header", [])
rows = data["rows"]
kg_reference = data["kgReference"]
candidate_size = data["candidateSize"]
column_metadata = data["column"]
target = data["target"]
type = data["types"]
_id = data["_id"]
dataset_name = data["datasetName"]
table_name = data["tableName"]

types_weights = data["typesWeights"]
predicates_weights = data["predicatesWeights"]
obj_row_update = {"status": "DONE", "time": None}

if len(column_metadata) == 0:
    column_metadata, target = compute_datatype(rows, lamAPI)
    column_metadata[str(target["SUBJ"])] = "SUBJ"
    obj_row_update["column"] = column_metadata
    obj_row_update["metadata"] = {
        "column": [{"idColumn": int(id_col), "tag": column_metadata[id_col]} for id_col in column_metadata]
    }
    obj_row_update["target"] = target

cells_set = pre_processing(header, rows, column_metadata, type, candidate_size)
cea = CEAProcess(data, lamAPI, rankers, target, log_c, type, kg_ref=kg_reference, size=candidate_size)
(results_cea, candidates) = cea.compute()
winning_candidates = [row["winningCandidates"] for row in results_cea]
keys = {"datasetName":dataset_name, "tableName":table_name}
cpa = CPAProcess(winning_candidates, keys, target, len(rows[0]["data"]), kg_ref=kg_reference)
results_cpa = cpa.compute()
cta = CTAProcess(winning_candidates, keys, target, len(rows[0]["data"]), kg_ref=kg_reference)
results_cta = cta.compute()
cpa_data, cta_data = (cpa._cpa, cta._cta)
if len(types_weights) > 0:
    cta_data = types_weights
if len(predicates_weights) > 0:
    cpa_data = predicates_weights     

revision = RevisionProcess(rankers, results_cea, candidates, cpa._cpa, cta._cta, target["SUBJ"])
revision.compute()
end = time.time()
execution_time = round(end - start, 2)
execution_time

# %%
import os
import sys
import time
import traceback
import joblib
import redis
import utils.utils as utils
from keras.models import load_model
from phases.data_preparation import DataPreparation
from wrapper.lamAPI import LamAPI
from wrapper.mongodb_conn import get_collection
from phases.lookup import Lookup
from phases.feauturesExtraction import FeauturesExtraction
from phases.prediction import Prediction
from phases.featuresExtractionRevision import FeaturesExtractionRevision
from phases.storage import Storage


neural2_path = "./ml_models/neural_network2.h5"


model = load_model(neural2_path)
               

start = time.time()

REDIS_ENDPOINT = os.environ["REDIS_ENDPOINT"]
REDIS_JOB_DB = int(os.environ["REDIS_JOB_DB"])
LAMAPI_HOST, LAMAPI_PORT = os.environ["LAMAPI_ENDPOINT"].split(":")
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]

lamAPI = LamAPI(LAMAPI_HOST, LAMAPI_PORT, LAMAPI_TOKEN)
job_active = redis.Redis(host=REDIS_ENDPOINT, db=REDIS_JOB_DB)

row_c = get_collection('row')
log_c = get_collection('log')
cea_prelinking_c = get_collection('ceaPrelinking')
header_cea_c = get_collection('ceaHeader')
cea_c = get_collection('cea')
cpa_c = get_collection('cpa')
cta_c = get_collection('cta')
header_candidate_scored_c = get_collection('headerCandidateScored')
candidate_scored_c = get_collection('candidateScored')
data = row_c.find_one({"datasetName": "HardTableR3-2021_100_m3", "tableName": "0B5GPQG2"})


if data is None:
    job_active.set("STOP", "")
    sys.exit(0)

header = data.get("header", [])
rows = data["rows"]
kg_reference = data["kgReference"]
limit = data["candidateSize"]
column_metadata = data["column"]
target = data["target"]
_type = data["types"]
_id = data["_id"]
dataset_name = data["datasetName"]
table_name = data["tableName"]

types_weights = data["typesWeights"]
predicates_weights = data["predicatesWeights"]
obj_row_update = {"status": "DONE", "time": None}
dp = DataPreparation(rows, lamAPI)
if len(column_metadata) == 0:
    column_metadata, target = dp.compute_datatype()
    column_metadata[str(target["SUBJ"])] = "SUBJ"
    obj_row_update["column"] = column_metadata
    obj_row_update["metadata"] = {
        "column": [{"idColumn": int(id_col), "tag": column_metadata[id_col]} for id_col in column_metadata]
    }
    obj_row_update["target"] = target
    
metadata = {
    "datasetName": dataset_name,
    "tableName": table_name,
    "kgReference": kg_reference
}

collections = {
    "ceaPrelinking": cea_prelinking_c,
    "cea": cea_c,
    "cta": cta_c,
    "cpa": cpa_c,
    "candidateScored": candidate_scored_c
}

dp.rows_normalization()
l = Lookup(data, lamAPI, target, log_c, kg_reference, limit)
rows = l.get_rows()
features = FeauturesExtraction(rows, lamAPI).compute_feautures()
Prediction(rows, features, model).compute_prediction("cea")
cea_preliking_data = utils.get_cea_pre_linking_data(metadata, rows)
revision = FeaturesExtractionRevision(rows)
features = revision.compute_features()
Prediction(rows, features, model).compute_prediction("score")
storage = Storage(metadata, cea_preliking_data, rows, revision._cta, revision._cpa, collections)
# Out:
# 2023-03-29 09:07:29.137494: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-29 09:07:29.281783: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-29 09:07:29.286805: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-29 09:07:29.286831: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-29 09:07:30.010741: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-29 09:07:30.010857: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-29 09:07:30.010869: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-29 09:07:31.951141: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-29 09:07:31.951204: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-29 09:07:31.951229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (42956c55e859): /proc/driver/nvidia/version does not exist
# 2023-03-29 09:07:31.951531: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 45/45 [==============================] - 0s 2ms/step
# 45/45 [==============================] - 0s 2ms/step

# %%
rows[0].get_subject_cell()._id_col
# Out:
# 0

# %%
target
# Out:
# {'SUBJ': 0, 'NE': [1, 2], 'LIT': [0], 'LIT_DATATYPE': {'0': 'DATETIME'}}

# %%
revision._cpa_weights
# Out:
# {'0': {'P2048': 46.02499999999999,
#   'P2049': 35.444,
#   'P1082': 0.002,
#   'P2046': 0.014,
#   'P1081': 0.048,
#   'P2044': 0.216},
#  '1': {}}

# %%
revision._cpa
# Out:
# {'0': {'P2048': 0.97,
#   'P2049': 0.74,
#   'P1082': 0.0,
#   'P2046': 0.0,
#   'P1081': 0.0,
#   'P2044': 0.01},
#  '1': {}}

# %%
cta = revision._cta
cta
# Out:
# {'0': {'Q18965': 1.0}, '1': {}}

# %%
cta = storage.store_cta_data()

# %%
max(revision._cta['0'])
# Out:
# 'Q930752'

# %%
import heapq
from operator import itemgetter

n = 5

items = revision._cta['0']

topitems = heapq.nlargest(n, items.items(), key=itemgetter(1))  # Use .iteritems() on Py2
topitemsasdict = dict(topitems)
topitemsasdict
# Out:
# {'Q429785': 0.33,
#  'Q108586636': 0.27,
#  'Q43229': 0.27,
#  'Q16521': 0.27,
#  'Q11424': 0.27}

# %%
rows[9].get_cells()[0].candidates()

# %%
rows[1].get_cells()[0].candidates()

# %%
import json
print(json.dumps(rows[9].get_cells()[0].candidates()))
# Out:
# [{"id": "Q55213748", "name": "planta dos terrenos de anna luiza do espirito santo", "description": "work by joaquim rodrigues antunes junior 2/2", "types": [{"id": "Q18965", "name": "floor plan"}], "features": {"ntoken": 9, "popularity": 1, "pos_score": 0.03, "es_score": 200.64, "es_diff_score": 0.851958, "ed": 1.0, "jaccard": 1.0, "jaccardNgram": 1.0, "cosine_similarity": 1.0, "p_subj_ne": 0, "p_subj_lit": 1.0, "p_obj_ne": 0, "desc": 0.0, "descNgram": 0.038, "cpa": 0.92, "cpaMax": 1.0, "cta": 1.0, "ctaMax": 1.0, "cea": 0.967, "diff": 0.007000000000000006}, "matches": {"0": [], "1": [{"p": "P2048", "o": "+53", "s": 0.835}, {"p": "P2049", "o": "+63.5", "s": 1.0}]}, "predicates": {"0": {}, "1": {"P2048": 0.835, "P2049": 1.0}}, "match": false, "score": 0.98}, {"id": "Q55213747", "name": "planta dos terrenos de anna luiza do espirito santo", "description": "work by joaquim rodrigues antunes junior 1/2", "types": [{"id": "Q18965", "name": "floor plan"}], "features": {"ntoken": 9, "popularity": 1, "pos_score": 0.01, "es_score": 203.34, "es_diff_score": 0.007757, "ed": 1.0, "jaccard": 1.0, "jaccardNgram": 1.0, "cosine_similarity": 1.0, "p_subj_ne": 0, "p_subj_lit": 0.811, "p_obj_ne": 0, "desc": 0.0, "descNgram": 0.038, "cpa": 0.81, "cpaMax": 0.811, "cta": 1.0, "ctaMax": 1.0, "cea": 0.974, "diff": 0.0}, "matches": {"0": [], "1": [{"p": "P2048", "o": "+51", "s": 0.803}, {"p": "P2049", "o": "+51.5", "s": 0.811}]}, "predicates": {"0": {}, "1": {"P2048": 0.803, "P2049": 0.811}}, "match": false, "score": 0.977}, {"id": "Q55213752", "name": "planta dos terrenos de anna luiza do espirito santo", "description": "work by joaquim rodrigues antunes junior and p. claparede 1/2", "types": [{"id": "Q18965", "name": "floor plan"}], "features": {"ntoken": 9, "popularity": 1, "pos_score": 0.02, "es_score": 201.77, "es_diff_score": 0.005648, "ed": 1.0, "jaccard": 1.0, "jaccardNgram": 1.0, "cosine_similarity": 1.0, "p_subj_ne": 0, "p_subj_lit": 1.0, "p_obj_ne": 0, "desc": 0.0, "descNgram": 0.031, "cpa": 0.89, "cpaMax": 1.0, "cta": 1.0, "ctaMax": 1.0, "cea": 0.963, "diff": 0.01100000000000001}, "matches": {"0": [], "1": [{"p": "P2048", "o": "+63.5", "s": 1.0}, {"p": "P2049", "o": "+49.7", "s": 0.783}]}, "predicates": {"0": {}, "1": {"P2048": 1.0, "P2049": 0.783}}, "match": false, "score": 0.977}, {"id": "Q55364821", "name": "planta dos terrenos junto \u00e0 vila de santo amaro", "description": "work by henrique julio ruffin and alvaro b. menezes", "types": [{"id": "Q18965", "name": "floor plan"}], "features": {"ntoken": 9, "popularity": 1, "pos_score": 0.04, "es_score": 108.34, "es_diff_score": 0.067851, "ed": 0.61, "jaccard": 0.56, "jaccardNgram": 0.54, "cosine_similarity": 0.78, "p_subj_ne": 0, "p_subj_lit": 0.92, "p_obj_ne": 0, "desc": 0.0, "descNgram": 0.0, "cpa": 0.8, "cpaMax": 0.671, "cta": 1.0, "ctaMax": 1.0, "cea": 0.001, "diff": 0.973}, "matches": {"0": [], "1": [{"p": "P2048", "o": "+69", "s": 0.92}, {"p": "P2049", "o": "+94.6", "s": 0.671}]}, "predicates": {"0": {}, "1": {"P2048": 0.92, "P2049": 0.671}}, "match": false, "score": 0.001}, {"id": "Q55211562", "name": "planta de parte dos terrenos do s\u00edtio das corujas", "description": "work by sebasti\u00e3o penteado junior 2/2", "types": [{"id": "Q18965", "name": "floor plan"}], "features": {"ntoken": 9, "popularity": 1, "pos_score": 0.07, "es_score": 100.43, "es_diff_score": 0.00412, "ed": 0.37, "jaccard": 0.56, "jaccardNgram": 0.46, "cosine_similarity": 0.74, "p_subj_ne": 0, "p_subj_lit": 0.893, "p_obj_ne": 0, "desc": 0.0, "descNgram": 0.0, "cpa": 0.84, "cpaMax": 0.782, "cta": 1.0, "ctaMax": 1.0, "cea": 0.001, "diff": 0.973}, "matches": {"0": [], "1": [{"p": "P2048", "o": "+56.7", "s": 0.893}, {"p": "P2049", "o": "+81.2", "s": 0.782}]}, "predicates": {"0": {}, "1": {"P2048": 0.893, "P2049": 0.782}}, "match": false, "score": 0.0}, {"id": "Q55211560", "name": "planta de parte dos terrenos do s\u00edtio das corujas", "description": "work by sebasti\u00e3o penteado junior 1/2", "types": [{"id" ...

# %%
cea_prelinking_c.insert_one(cea_preliking_data[0])

# %%
type(cea_preliking_data[0]["winningCandidates"][0][0]["types"])
# Out:
# list

# %%
type(cea_preliking_data[0]["winningCandidates"][0]["types"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 type(cea_preliking_data[0]["winningCandidates"][0]["types"])
#
# TypeError: list indices must be integers or slices, not str

# %%
type(cea_preliking_data[0]["types"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 type(cea_preliking_data[0]["types"])
#
# KeyError: 'types'

# %%
cea_preliking_data[0]

# %%
l.get_rows()[1].get_cells()[1].candidates()
# Out:
# []

# %%
import pickle
# Load the Model back from file
logistic_r1_path = "logistic1_r1.pkl"
with open(logistic_r1_path, 'rb') as file:  
    logistic_r1_path = pickle.load(file)

# %%
pip install tensorflow
# Out:
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 flatbuffers-23.3.3 gast-0.4.0 google-auth-2.16.3 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.53.0 jax-0.4.7 keras-2.12.0 libclang-16.0.0 markdown-3.4.3 ml_dtypes-0.0.4 opt-einsum-3.3.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.0 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.2.0 werkzeug-2.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
header_results

# %%
header_candidates

# %%
cta_data
# Out:
# {'0': {'Q33999': 0.667,
#   'Q488205': 0.667,
#   'Q639669': 0.667,
#   'Q2405480': 0.667,
#   'Q177220': 0.667,
#   'Q36834': 0.333,
#   'Q10798782': 0.667,
#   'Q10800557': 0.667,
#   'Q9648008': 0.333,
#   'Q55960555': 0.667,
#   'Q5': 1.0,
#   'Q486748': 0.333,
#   'Q855091': 0.333,
#   'Q1327329': 0.333,
#   'Q1028181': 0.333,
#   'Q482980': 0.333,
#   'Q3282637': 0.333,
#   'Q970153': 0.333,
#   'Q2259451': 0.333},
#  '1': {'Q13218391': 0.333,
#   'Q62049': 0.333,
#   'Q1093829': 0.667,
#   'Q1549591': 1.0,
#   'Q50330360': 0.333,
#   'Q515': 1.0,
#   'Q1388464': 0.333,
#   'Q21507383': 0.333,
#   'Q208511': 0.333,
#   'Q2264924': 0.333,
#   'Q51929311': 0.333,
#   'Q15063611': 0.333,
#   'Q1637706': 0.333},
#  '2': {'Q3624078': 1.0,
#   'Q1520223': 0.667,
#   'Q5255892': 0.667,
#   'Q512187': 0.667,
#   'Q1489259': 0.667,
#   'Q6256': 1.0,
#   'Q99541706': 0.667,
#   'Q223832': 0.333,
#   'Q202686': 0.333,
#   'Q43702': 0.333}}

# %%
result = lamAPI.lookup("wikidata")
result

# %%
Pickled_LR_Model.pre([])

# %%
results_cea[0]["winningCandidates"][0][0]['features'].keys()
# Out:
# dict_keys(['ntoken', 'popularity', 'pos_score', 'es_score', 'es_diff_score', 'ed', 'jaccard', 'jaccardNgram', 'cosine_similarity', 'p_subj_ne', 'p_subj_lit', 'p_obj_ne', 'desc', 'descNgram', 'cea', 'cpa', 'cpaMax', 'cta', 'ctaMax'])

# %%
features = ['ntoken', 'popularity', 'pos_score', 'es_score', 'es_diff_score', 'ed', 'jaccard', 'jaccardNgram', 'cosine_similarity', 'p_subj_ne', 'p_subj_lit', 'p_obj_ne', 'desc', 'descNgram']

# %%
temp = results_cea[0]["winningCandidates"][1][0]['features']
Xnew = [temp[feature] for feature in features]

# %%
import numpy as np
predictions = Pickled_LR_Model.predict([Xnew])
predictions
# Out:
# 1/1 [==============================] - 0s 47ms/step
# array([[0.06421909, 0.93578094]], dtype=float32)

# %%
predictions[0][1]
# Out:
# 0.93578094

# %%
seq_predictions=Pickled_LR_Model.predict([Xnew])
print('Outputs shape')    
print(seq_predictions.shape) # prints (n,1) but  need (n,)
seq_predictions=np.transpose(seq_predictions)[0]  # transformation to get (n,)
print(seq_predictions.shape)  # now the shape is (n,)
# Applying transformation to get binary values predictions with 0.5 as thresold
seq_predictions = list(map(lambda x: 0 if x<0.5 else 1, seq_predictions))
# Out:
# 1/1 [==============================] - 0s 39ms/step
# Outputs shape
# (1, 2)
# (1,)

# %%
results_cea[0]
# Out:
# {'datasetName': 'Dataset1',
#  'tableName': 'Test1',
#  'row': 1,
#  'data': ['zooey deschanel', 'los angeles', 'united states'],
#  'winningCandidates': [[{'id': 'Q191719',
#     'name': 'zooey deschanel',
#     'description': 'american actress, model, and singer-songwriter',
#     'types': [{'id': 'Q33999', 'name': 'actor'},
#      {'id': 'Q488205', 'name': 'singer-songwriter'},
#      {'id': 'Q639669', 'name': 'musician'},
#      {'id': 'Q2405480', 'name': 'voice actor'},
#      {'id': 'Q177220', 'name': 'singer'},
#      {'id': 'Q36834', 'name': 'composer'},
#      {'id': 'Q10798782', 'name': 'television actor'},
#      {'id': 'Q10800557', 'name': 'film actor'},
#      {'id': 'Q9648008', 'name': 'banjoist'},
#      {'id': 'Q55960555', 'name': 'recording artist'},
#      {'id': 'Q5', 'name': 'human'}],
#     'match_count': {'obj': 2, 'lit': 0, 'rel': 0},
#     'matches': {'1': [{'p': 'P19', 'o': 'Q65', 's': 1.0}],
#      '2': [{'p': 'P27', 'o': 'Q30', 's': 1.0}]},
#     'features': {'ntoken': 2,
#      'popularity': 71,
#      'pos_score': 0.02,
#      'es_score': 78.49,
#      'es_diff_score': 0.0,
#      'ed': 1.0,
#      'jaccard': 1.0,
#      'jaccardNgram': 1.0,
#      'cosine_similarity': 1.0,
#      'p_subj_ne': 2.0,
#      'p_subj_lit': 0,
#      'p_obj_ne': 0,
#      'desc': 0.0,
#      'descNgram': 0.062,
#      'cpa': 1.0,
#      'cpaMax': 1.0,
#      'cta': 0.637,
#      'ctaMax': 1.0,
#      'cea': 0.999,
#      'diff': 0.0},
#     'pred': {'1': {'P19': 1.0}, '2': {'P27': 1.0}},
#     'match': True,
#     'score': 0.946,
#     'neural1_score': 0.955,
#     'neural2_score': 0.946,
#     'logistic1_score': 1.0,
#     'logistic2_score': 1.0}],
#   [{'id': 'Q65',
#     'name': 'los angeles',
#     'description': 'city in and county seat of los angeles county, california, united states; second largest city in the united states by population',
#     'types': [{'id': 'Q13218391', 'name': 'charter city'},
#      {'id': 'Q62049', 'name': 'county seat'},
#      {'id': 'Q1093829', 'name': 'city of the United States'},
#      {'id': 'Q1549591', 'name': 'big city'},
#      {'id': 'Q50330360', 'name': 'second largest city'},
#      {'id': 'Q515', 'name': 'city'}],
#     'match_count': {'obj': 1, 'lit': 0, 'rel': 0},
#     'matches': {'0': [], '2': [{'p': 'P17', 'o': 'Q30', 's': 1.0}]},
#     'features': {'ntoken': 2,
#      'popularity': 258,
#      'pos_score': 0.04,
#      'es_score': 51.08,
#      'es_diff_score': 0.000604,
#      'ed': 1.0,
#      'jaccard': 1.0,
#      'jaccardNgram': 1.0,
#      'cosine_similarity': 1.0,
#      'p_subj_ne': 1.0,
#      'p_subj_lit': 0,
#      'p_obj_ne': 2.0,
#      'desc': 0.222,
#      'descNgram': 0.269,
#      'cpa': 1.0,
#      'cpaMax': 1.0,
#      'cta': 0.611,
#      'ctaMax': 1.0,
#      'cea': 1.0,
#      'diff': 0.0},
#     'pred': {'0': {}, '2': {'P17': 1.0}},
#     'match': True,
#     'score': 0.999,
#     'neural1_score': 0.987,
#     'neural2_score': 0.999,
#     'logistic1_score': 1.0,
#     'logistic2_score': 0.999}],
#   [{'id': 'Q30',
#     'name': 'united states',
#     'description': 'sovereign state in north america',
#     'types': [{'id': 'Q3624078', 'name': 'sovereign state'},
#      {'id': 'Q1520223', 'name': 'constitutional republic'},
#      {'id': 'Q5255892', 'name': 'democratic republic'},
#      {'id': 'Q512187', 'name': 'federal republic'},
#      {'id': 'Q1489259', 'name': 'superpower'},
#      {'id': 'Q6256', 'name': 'country'},
#      {'id': 'Q99541706', 'name': 'historical unrecognized state'}],
#     'match_count': {'obj': 0, 'lit': 0, 'rel': 0},
#     'matches': {'0': [], '1': []},
#     'features': {'ntoken': 2,
#      'popularity': 391,
#      'pos_score': 0.02,
#      'es_score': 43.16,
#      'es_diff_score': 0.000357,
#      'ed': 1.0,
#      'jaccard': 1.0,
#      'jaccardNgram': 1.0,
#      'cosine_similarity': 1.0,
#      'p_subj_ne': 0,
#      'p_subj_lit': 0,
#      'p_obj_ne': 2.0,
#      'desc': 0.0,
#      'descNgram': 0.125,
#      'cpa': 0.0,
#      'cpaMax': 0,
#      'cta': 0.762,
#      'ctaMax': 1.0,
#      'cea': 0.999,
#      'diff': 0.0},
#     'pred': {'0': {}, '1': {}},
#     'match': True,
#     'score': 0.999,
#     'neural1_score': 0.999,
#     'neural2_score': 0.999,
#     'logistic1_score': 1.0,
#     'logistic2_score': 1.0}]],
#  'cea': {'0': 'Q191719', '1': 'Q65', '2': 'Q30'},
#  'kgReference': 'wikidata',
#  'confidence': 2.944}

# %%
ynew = Pickled_LR_Model.predict([Xnew])
# show the inputs and predicted outputs
for i in range(len(Xnew)):
    print("X=%s, Predicted=%s" % (Xnew[i], ynew[i]))

# %%
results_cea[0]
# Out:
# {'datasetName': 'Dataset1',
#  'tableName': 'Test1',
#  'row': 1,
#  'data': ['zooey deschanel', 'los angeles', 'united states'],
#  'winningCandidates': [[{'id': 'Q191719',
#     'name': 'zooey deschanel',
#     'description': 'american actress, model, and singer-songwriter',
#     'types': [{'id': 'Q33999', 'name': 'actor'},
#      {'id': 'Q488205', 'name': 'singer-songwriter'},
#      {'id': 'Q639669', 'name': 'musician'},
#      {'id': 'Q2405480', 'name': 'voice actor'},
#      {'id': 'Q177220', 'name': 'singer'},
#      {'id': 'Q36834', 'name': 'composer'},
#      {'id': 'Q10798782', 'name': 'television actor'},
#      {'id': 'Q10800557', 'name': 'film actor'},
#      {'id': 'Q9648008', 'name': 'banjoist'},
#      {'id': 'Q55960555', 'name': 'recording artist'},
#      {'id': 'Q5', 'name': 'human'}],
#     'match_count': {'obj': 2, 'lit': 0, 'rel': 0},
#     'matches': {'1': [{'p': 'P19', 'o': 'Q65', 's': 1.0}],
#      '2': [{'p': 'P27', 'o': 'Q30', 's': 1.0}]},
#     'features': {'ntoken': 2,
#      'popularity': 71,
#      'pos_score': 0.02,
#      'es_score': 78.49,
#      'es_diff_score': 0.0,
#      'ed': 1.0,
#      'jaccard': 1.0,
#      'jaccardNgram': 1.0,
#      'cosine_similarity': 1.0,
#      'p_subj_ne': 2.0,
#      'p_subj_lit': 0,
#      'p_obj_ne': 0,
#      'desc': 0.0,
#      'descNgram': 0.062,
#      'cea': 0.994,
#      'cpa': 2.0,
#      'cpaMax': 1.0,
#      'cta': 3.335,
#      'ctaMax': 0.667},
#     'pred': {'1': {'P19': 1.0}, '2': {'P27': 1.0}},
#     'match': True,
#     'score': 0.994,
#     'neural1_score': 0.994,
#     'neural2_score': 0.991,
#     'logistic1_score': 1.0,
#     'logistic2_score': 1.0}],
#   [{'id': 'Q65',
#     'name': 'los angeles',
#     'description': 'city in and county seat of los angeles county, california, united states; second largest city in the united states by population',
#     'types': [{'id': 'Q13218391', 'name': 'charter city'},
#      {'id': 'Q62049', 'name': 'county seat'},
#      {'id': 'Q1093829', 'name': 'city of the United States'},
#      {'id': 'Q1549591', 'name': 'big city'},
#      {'id': 'Q50330360', 'name': 'second largest city'},
#      {'id': 'Q515', 'name': 'city'}],
#     'match_count': {'obj': 1, 'lit': 0, 'rel': 0},
#     'matches': {'0': [], '2': [{'p': 'P17', 'o': 'Q30', 's': 1.0}]},
#     'features': {'ntoken': 2,
#      'popularity': 258,
#      'pos_score': 0.04,
#      'es_score': 51.08,
#      'es_diff_score': 0.000604,
#      'ed': 1.0,
#      'jaccard': 1.0,
#      'jaccardNgram': 1.0,
#      'cosine_similarity': 1.0,
#      'p_subj_ne': 1.0,
#      'p_subj_lit': 0,
#      'p_obj_ne': 2.0,
#      'desc': 0.222,
#      'descNgram': 0.269,
#      'cea': 0.999,
#      'cpa': 1.0,
#      'cpaMax': 1.0,
#      'cta': 2.666,
#      'ctaMax': 1.0},
#     'pred': {'0': {}, '2': {'P17': 1.0}},
#     'match': True,
#     'score': 0.999,
#     'neural1_score': 0.999,
#     'neural2_score': 1.0,
#     'logistic1_score': 1.0,
#     'logistic2_score': 1.0}],
#   [{'id': 'Q30',
#     'name': 'united states',
#     'description': 'sovereign state in north america',
#     'types': [{'id': 'Q3624078', 'name': 'sovereign state'},
#      {'id': 'Q1520223', 'name': 'constitutional republic'},
#      {'id': 'Q5255892', 'name': 'democratic republic'},
#      {'id': 'Q512187', 'name': 'federal republic'},
#      {'id': 'Q1489259', 'name': 'superpower'},
#      {'id': 'Q6256', 'name': 'country'},
#      {'id': 'Q99541706', 'name': 'historical unrecognized state'}],
#     'match_count': {'obj': 0, 'lit': 0, 'rel': 0},
#     'matches': {'0': [], '1': []},
#     'features': {'ntoken': 2,
#      'popularity': 391,
#      'pos_score': 0.02,
#      'es_score': 43.16,
#      'es_diff_score': 0.000357,
#      'ed': 1.0,
#      'jaccard': 1.0,
#      'jaccardNgram': 1.0,
#      'cosine_similarity': 1.0,
#      'p_subj_ne': 0,
#      'p_subj_lit': 0,
#      'p_obj_ne': 2.0,
#      'desc': 0.0,
#      'descNgram': 0.125,
#      'cea': 1.0,
#      'cpa': 0.0,
#      'cpaMax': 0,
#      'cta': 3.668,
#      'ctaMax': 1.0},
#     'pred': {'0': {}, '1': {}},
#     'match': True,
#     'score': 1.0,
#     'neural1_score': 1.0,
#     'neural2_score': 1.0,
#     'logistic1_score': 1.0,
#     'logistic2_score': 1.0}]],
#  'cea': {'0': 'Q191719', '1': 'Q65', '2': 'Q30'},
#  'kgReference': 'wikidata',
#  'confidence': 2.993000030517578}

# %%
from wrapper.lamAPI import LamAPI
from wrapper.mongodb_conn import get_collection
import os

LAMAPI_HOST, LAMAPI_PORT = os.environ["LAMAPI_ENDPOINT"].split(":")
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]


lamAPI = LamAPI(LAMAPI_HOST, LAMAPI_PORT, LAMAPI_TOKEN, kg="crunchbase")
lamAPI.literals(["fe41b3a3-3ad1-4b78-ba21-765d2339a787"])
# Out:
# {'fe41b3a3-3ad1-4b78-ba21-765d2339a787': {'literals': {'STRING': {'facebook_url': ['https://www.facebook.com/OfficialTfGM'],
#     'primary_role': ['company'],
#     'short_description': ['Transport for Greater Manchester is UK based company that oversees transport and travel in Greater Manchester.'],
#     'email': ['customer.relations@tfgm.com'],
#     'homepage_url': ['https://tfgm.com'],
#     'type': ['organization'],
#     'country_code': ['GBR'],
#     'category_groups_list': ['Transportation,Travel and Tourism'],
#     'category_list': ['Public Transportation,Transportation,Travel'],
#     'alias1': ['tfgm'],
#     'phone': ['44 161 244 1000'],
#     'roles': ['company'],
#     'cb_url': ['https://www.crunchbase.com/organization/transport-for-greater-manchester'],
#     'uuid': ['fe41b3a3-3ad1-4b78-ba21-765d2339a787'],
#     'linkedin_url': ['https://www.linkedin.com/company/transportforgreatermanchester'],
#     'logo_url': ['https://res.cloudinary.com/crunchbase-production/image/upload/odejrfpbnyfhfrhonwcv'],
#     'twitter_url': ['https://twitter.com/officialtfgm'],
#     'domain': ['tfgm.com'],
#     'permalink': ['transport-for-greater-manchester'],
#     'status': ['operating']},
#    'NUMBER': {'rank': [451169.0]},
#    'DATETIME': {'updated_at': ['2022-03-02 12:23:29'],
#     'employee_count': ['501-1000'],
#     'created_at': ['2022-03-02 12:23:29'],
#     'founded_on': ['2011-01-01']}}}}

# %%
from wrapper.lamAPI import LamAPI
from wrapper.mongodb_conn import get_collection
import os

LAMAPI_HOST, LAMAPI_PORT = os.environ["LAMAPI_ENDPOINT"].split(":")
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]


lamAPI = LamAPI(LAMAPI_HOST, LAMAPI_PORT, LAMAPI_TOKEN, kg="wikidata")
lamAPI.literals(["Q31"])

# %%
lamAPI_wrapper.literal_recognizer([20, 50])

# %%
import os
from wrapper.lamAPI import LamAPI


LAMAPI_HOST = os.environ["LAMAPI_ENDPOINT"]
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]
lamapi_wrapper = LamAPI(LAMAPI_HOST, LAMAPI_TOKEN)
subject_objects = lamapi_wrapper.objects(["Q30"])
subject_objects

# %%
lamapi_wrapper.lookup("united states")
# Out:
# {'united states': [{'id': 'Q35657',
#    'name': 'United States states',
#    'description': 'constituent political entity sharing sovereignty as the United States of America',
#    'types': [{'id': 'Q28872924',
#      'name': 'designation for an administrative territorial entity of a single country'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 20,
#    'popularity': 0.14,
#    'pos_score': 0.01,
#    'es_score': 1.0,
#    'ed_score': 0.65,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 0.94},
#   {'id': 'Q30',
#    'name': 'United States',
#    'description': 'sovereign state in North America',
#    'types': [{'id': 'Q3624078', 'name': 'sovereign state'},
#     {'id': 'Q1520223', 'name': 'constitutional republic'},
#     {'id': 'Q5255892', 'name': 'democratic republic'},
#     {'id': 'Q512187', 'name': 'federal republic'},
#     {'id': 'Q1489259', 'name': 'superpower'},
#     {'id': 'Q6256', 'name': 'country'},
#     {'id': 'Q99541706', 'name': 'historical unrecognized state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.45,
#    'pos_score': 0.02,
#    'es_score': 0.989,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q36747',
#    'name': 'United States',
#    'description': 'pre-Columbian peoples of North, Central and South America and their descendants',
#    'types': [{'id': 'Q41710', 'name': 'ethnic group'},
#     {'id': 'Q851990', 'name': 'population group'},
#     {'id': 'Q16334295', 'name': 'group of humans'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.15,
#    'pos_score': 0.05,
#    'es_score': 0.986,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q164134',
#    'name': 'United States',
#    'description': "men's national association football team representing the USA",
#    'types': [{'id': 'Q6979593', 'name': 'national association football team'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.08,
#    'pos_score': 0.06,
#    'es_score': 0.984,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q334526',
#    'name': 'United States',
#    'description': "women's national association football team representing the United States",
#    'types': [{'id': 'Q23905105',
#      'name': "women's national association football team"}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.05,
#    'pos_score': 0.07,
#    'es_score': 0.983,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q861556',
#    'name': 'United States',
#    'description': 'U.S. federal government department concerning education',
#    'types': [{'id': 'Q2269756', 'name': 'ministry of education'},
#     {'id': 'Q910252', 'name': 'United States federal executive department'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.04,
#    'pos_score': 0.08,
#    'es_score': 0.981,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q1545509',
#    'name': 'United States',
#    'description': 'American ocean liner',
#    'types': [{'id': 'Q697196', 'name': 'ocean liner'},
#     {'id': 'Q2055880', 'name': 'passenger ship'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.02,
#    'pos_score': 0.09,
#    'es_score': 0.981,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q41700',
#    'name': 'United States',
#    'description': 'Wikimedia disambiguation page',
#    'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.02,
#    'pos_score': 0.1,
#    'es_score': 0.98,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q1499604',
#    'name': 'United States',
#    'description': 'Cancled American Super-Carrier project.',
#    'types': [{'id': 'Q1186981', 'name': 'supercarrier'},
#     {'id': 'Q16214696', 'name': 'ship project'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.02,
#    'pos_score': 0.11,
#    'es_score': 0.979,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q2534403',
#    'name': 'United States',
#    'description': 'American football team',
#    'types': [{'id': 'Q1194951', 'name': 'national sports team'},
#     {'id': 'Q106587004', 'name': 'national American football team'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.02,
#    'pos_score': 0.12,
#    'es_score': 0.978,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q2738955',
#    'name': 'United States',
#    'description': 'sports team representing the USA',
#    'types': [{'id': 'Q1194951', 'name': 'national sports team'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.02,
#    'pos_score': 0.13,
#    'es_score': 0.976,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q647635',
#    'name': 'United States',
#    'description': "Men's national beach soccer team representing the USA",
#    'types': [{'id': 'Q47460286', 'name': 'national beach soccer team'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.01,
#    'pos_score': 0.14,
#    'es_score': 0.976,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q3109672',
#    'name': 'United States',
#    'description': 'former United States federal executive department that was reorganized into the United States Postal Service in 1971',
#    'types': [{'id': 'Q2106202', 'name': 'postal services ministry'},
#     {'id': 'Q910252', 'name': 'United States federal executive department'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.01,
#    'pos_score': 0.15,
#    'es_score': 0.976,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q232865',
#    'name': 'United States',
#    'description': 'Wikimedia disambiguation page',
#    'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.01,
#    'pos_score': 0.16,
#    'es_score': 0.974,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q3590565',
#    'name': 'United States',
#    'description': '',
#    'types': [{'id': 'Q1194951', 'name': 'national sports team'},
#     {'id': 'Q15221215', 'name': 'rugby league team'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.01,
#    'pos_score': 0.17,
#    'es_score': 0.974,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q49042',
#    'name': 'United States Southern States',
#    'description': 'cultural region in the southeastern and south-central United States',
#    'types': [{'id': 'Q518261', 'name': 'cultural area'},
#     {'id': 'Q57766005', 'name': 'United States census region'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 4,
#    'length_mention': 13,
#    'length_entity': 29,
#    'popularity': 0.08,
#    'pos_score': 0.18,
#    'es_score': 0.973,
#    'ed_score': 0.45,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.84},
#   {'id': 'Q7406484',
#    'name': 'United States',
#    'description': "land warfare branch of El Salvador's military",
#    'types': [{'id': 'Q37726', 'name': 'army'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.01,
#    'pos_score': 0.21,
#    'es_score': 0.968,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q7893546',
#    'name': 'United States',
#    'description': 'cricket team',
#    'types': [{'id': 'Q1194951', 'name': 'national sports team'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.01,
#    'pos_score': 0.22,
#    'es_score': 0.968,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q4998389',
#    'name': 'United States',
#    'description': "U.S. Labor Department's division for international affairs",
#    'types': [{'id': 'Q327333', 'name': 'government agency'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.23,
#    'es_score': 0.965,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q3604334',
#    'name': 'United States',
#    'description': '',
#    'types': [{'id': 'Q151885', 'name': 'concept'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.01,
#    'pos_score': 0.24,
#    'es_score': 0.964,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q19040030',
#    'name': 'United States v. United States',
#    'description': '',
#    'types': [{'id': 'Q2334719', 'name': 'legal case'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 5,
#    'length_mention': 13,
#    'length_entity': 30,
#    'popularity': 0.0,
#    'pos_score': 0.25,
#    'es_score': 0.963,
#    'ed_score': 0.43,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 0.93},
#   {'id': 'Q16959097',
#    'name': 'United States',
#    'description': 'album by Paul Gilbert',
#    'types': [{'id': 'Q482994', 'name': 'album'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.26,
#    'es_score': 0.961,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q3965121',
#    'name': 'United States',
#    'description': 'television series',
#    'types': [{'id': 'Q5398426', 'name': 'television series'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.27,
#    'es_score': 0.96,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q7003802',
#    'name': 'United States',
#    'description': 'American filmmaker duo',
#    'types': [{'id': 'Q10648343', 'name': 'duo'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.28,
#    'es_score': 0.96,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q7417302',
#    'name': 'United States',
#    'description': 'Former US Army facility in New Jersey',
#    'types': [{'id': 'Q18691599', 'name': 'military facility'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.29,
#    'es_score': 0.96,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q5061268',
#    'name': 'United States',
#    'description': 'accountability and audit authority of the CIA',
#    'types': [{'id': 'Q7079371', 'name': 'office of the inspector general'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.3,
#    'es_score': 0.959,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q16971665',
#    'name': 'United States',
#    'description': 'administrative tribunal within the U.S. Department of Veterans Affairs',
#    'types': [{'id': 'Q327333', 'name': 'government agency'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.31,
#    'es_score': 0.959,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q7868808',
#    'name': 'United States',
#    'description': '',
#    'types': [{'id': 'Q11446', 'name': 'ship'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.32,
#    'es_score': 0.958,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q7233991',
#    'name': 'United States',
#    'description': 'US regulatory agency',
#    'types': [{'id': 'Q1752939',
#      'name': 'independent agency of the United States government'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.34,
#    'es_score': 0.958,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q61',
#    'name': 'United States Capital',
#    'description': 'capital city of the United States of America',
#    'types': [{'id': 'Q5119', 'name': 'capital'},
#     {'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q1549591', 'name': 'big city'},
#     {'id': 'Q475050', 'name': 'federal district'},
#     {'id': 'Q10864048',
#      'name': 'first-level administrative country subdivision'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.32,
#    'pos_score': 0.35,
#    'es_score': 0.958,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.88},
#   {'id': 'Q1204',
#    'name': 'Illinois, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 23,
#    'popularity': 0.25,
#    'pos_score': 0.36,
#    'es_score': 0.957,
#    'ed_score': 0.57,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.53,
#    'cosine_similarity': 0.83},
#   {'id': 'Q1537',
#    'name': 'Wisconsin, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 24,
#    'popularity': 0.24,
#    'pos_score': 0.37,
#    'es_score': 0.957,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.77},
#   {'id': 'Q1221',
#    'name': 'Idaho, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 20,
#    'popularity': 0.23,
#    'pos_score': 0.38,
#    'es_score': 0.957,
#    'ed_score': 0.65,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.67,
#    'cosine_similarity': 0.78},
#   {'id': 'Q18094',
#    'name': 'Honolulu, United States',
#    'description': 'city in and county seat of Honolulu County, Hawaii, United States, that is also the capital city of Hawaii',
#    'types': [{'id': 'Q62049', 'name': 'county seat'},
#     {'id': 'Q21518270',
#      'name': 'state or insular area capital of the United States'},
#     {'id': 'Q1549591', 'name': 'big city'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 23,
#    'popularity': 0.2,
#    'pos_score': 0.39,
#    'es_score': 0.957,
#    'ed_score': 0.57,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.53,
#    'cosine_similarity': 0.8},
#   {'id': 'Q6346',
#    'name': 'Indianapolis, United States',
#    'description': 'city in and county seat of Marion County, Indiana, United States and the Indiana federated state capital city',
#    'types': [{'id': 'Q62049', 'name': 'county seat'},
#     {'id': 'Q21518270',
#      'name': 'state or insular area capital of the United States'},
#     {'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q1074523', 'name': 'planned community'},
#     {'id': 'Q1549591', 'name': 'big city'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 27,
#    'popularity': 0.17,
#    'pos_score': 0.4,
#    'es_score': 0.957,
#    'ed_score': 0.48,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.42,
#    'cosine_similarity': 0.8},
#   {'id': 'Q1297',
#    'name': 'Chicago, United States',
#    'description': 'city and county seat of Cook County, Illinois, United States',
#    'types': [{'id': 'Q110071194', 'name': 'city of Illinois'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.3,
#    'pos_score': 0.41,
#    'es_score': 0.957,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.84},
#   {'id': 'Q816',
#    'name': 'Arizona, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.26,
#    'pos_score': 0.42,
#    'es_score': 0.957,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.78},
#   {'id': 'Q35073',
#    'name': 'Presiden United States',
#    'description': 'list of persons by position held',
#    'types': [{'id': 'Q66715753',
#      'name': 'Wikimedia list of persons by position held'},
#     {'id': 'Q13406463', 'name': 'Wikimedia list article'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.14,
#    'pos_score': 0.43,
#    'es_score': 0.957,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.83},
#   {'id': 'Q829',
#    'name': 'Utah, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 19,
#    'popularity': 0.24,
#    'pos_score': 0.45,
#    'es_score': 0.956,
#    'ed_score': 0.68,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.73,
#    'cosine_similarity': 0.85},
#   {'id': 'Q1345',
#    'name': 'Philadelphia, United States',
#    'description': 'largest city in Pennsylvania, United States',
#    'types': [{'id': 'Q21010817', 'name': 'city of Pennsylvania'},
#     {'id': 'Q1637706', 'name': 'million city'},
#     {'id': 'Q62049', 'name': 'county seat'},
#     {'id': 'Q5888666', 'name': 'home rule municipality of Pennsylvania'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 27,
#    'popularity': 0.21,
#    'pos_score': 0.46,
#    'es_score': 0.956,
#    'ed_score': 0.48,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.44,
#    'cosine_similarity': 0.8},
#   {'id': 'Q8652',
#    'name': 'Miami, United States',
#    'description': 'city in Miami-Dade County, Florida, United States',
#    'types': [{'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q62049', 'name': 'county seat'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 20,
#    'popularity': 0.21,
#    'pos_score': 0.47,
#    'es_score': 0.956,
#    'ed_score': 0.65,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.67,
#    'cosine_similarity': 0.84},
#   {'id': 'Q12439',
#    'name': 'Detroit, United States',
#    'description': 'city in and county seat of Wayne County, Michigan, United States',
#    'types': [{'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q62049', 'name': 'county seat'},
#     {'id': 'Q902814', 'name': 'border town'},
#     {'id': 'Q1549591', 'name': 'big city'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.19,
#    'pos_score': 0.49,
#    'es_score': 0.956,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.81},
#   {'id': 'Q171224',
#    'name': 'Eugene, United States',
#    'description': 'city in Lane County, Oregon, United States',
#    'types': [{'id': 'Q63440326', 'name': 'city of Oregon'},
#     {'id': 'Q62049', 'name': 'county seat'},
#     {'id': 'Q1093829', 'name': 'city of the United States'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.09,
#    'pos_score': 0.5,
#    'es_score': 0.956,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.8},
#   {'id': 'Q11208',
#    'name': 'United States Pentegon',
#    'description': 'headquarters of the United States Department of Defense; named after the shape of the building, a polygon with five (greek: penta) sides',
#    'types': [{'id': 'Q7540126', 'name': 'headquarters'},
#     {'id': 'Q16831714', 'name': 'government building'},
#     {'id': 'Q1021645', 'name': 'office building'},
#     {'id': 'Q570116', 'name': 'tourist attraction'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.11,
#    'pos_score': 0.52,
#    'es_score': 0.956,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.82},
#   {'id': 'Q25301',
#    'name': 'Washington, United States',
#    'description': 'Wikimedia disambiguation page',
#    'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 25,
#    'popularity': 0.14,
#    'pos_score': 0.53,
#    'es_score': 0.956,
#    'ed_score': 0.52,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.47,
#    'cosine_similarity': 0.84},
#   {'id': 'Q1649',
#    'name': 'Oklahoma, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 23,
#    'popularity': 0.24,
#    'pos_score': 0.54,
#    'es_score': 0.956,
#    'ed_score': 0.57,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.53,
#    'cosine_similarity': 0.8},
#   {'id': 'Q16551',
#    'name': 'Vermont, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.24,
#    'pos_score': 0.55,
#    'es_score': 0.956,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.84},
#   {'id': 'Q7976',
#    'name': 'United States accents',
#    'description': 'set of dialects of the English language spoken in the United States',
#    'types': [{'id': 'Q951873', 'name': 'ethnolect'},
#     {'id': 'Q33742', 'name': 'natural language'},
#     {'id': 'Q33384', 'name': 'dialect'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.08,
#    'pos_score': 0.57,
#    'es_score': 0.956,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.84},
#   {'id': 'Q29552',
#    'name': 'United States Democrats',
#    'description': 'political party in the United States',
#    'types': [{'id': 'Q7278', 'name': 'political party'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 23,
#    'popularity': 0.14,
#    'pos_score': 0.58,
#    'es_score': 0.956,
#    'ed_score': 0.57,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.53,
#    'cosine_similarity': 0.86},
#   {'id': 'Q100',
#    'name': 'Boston, United States',
#    'description': 'city in and state capital of Massachusetts, United States',
#    'types': [{'id': 'Q1549591', 'name': 'big city'},
#     {'id': 'Q21518270',
#      'name': 'state or insular area capital of the United States'},
#     {'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q62049', 'name': 'county seat'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.22,
#    'pos_score': 0.59,
#    'es_score': 0.956,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.82},
#   {'id': 'Q11268',
#    'name': 'United States Congresses',
#    'description': 'bicameral legislature of the United States',
#    'types': [{'id': 'Q189445', 'name': 'bicameral legislature'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 24,
#    'popularity': 0.12,
#    'pos_score': 0.6,
#    'es_score': 0.956,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.88},
#   {'id': 'Q173',
#    'name': 'Alabama, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.26,
#    'pos_score': 0.61,
#    'es_score': 0.956,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.79},
#   {'id': 'Q1494',
#    'name': 'Mississippi, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 26,
#    'popularity': 0.24,
#    'pos_score': 0.62,
#    'es_score': 0.956,
#    'ed_score': 0.5,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.8},
#   {'id': 'Q66096',
#    'name': 'United States Sen.',
#    'description': 'upper house of the United States Congress',
#    'types': [{'id': 'Q2570643', 'name': 'senate'},
#     {'id': 'Q110315658', 'name': 'elected legislative house'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 18,
#    'popularity': 0.11,
#    'pos_score': 0.63,
#    'es_score': 0.956,
#    'ed_score': 0.72,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.8,
#    'cosine_similarity': 0.89},
#   {'id': 'Q7890849',
#    'name': 'United States',
#    'description': 'Independent investigative and prosecutorial body of the United States federal government.',
#    'types': [{'id': 'Q1752939',
#      'name': 'independent agency of the United States government'},
#     {'id': 'Q327333', 'name': 'government agency'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 2,
#    'length_mention': 13,
#    'length_entity': 13,
#    'popularity': 0.0,
#    'pos_score': 0.64,
#    'es_score': 0.956,
#    'ed_score': 1.0,
#    'jaccard_score': 1.0,
#    'jaccardNgram_score': 1.0,
#    'cosine_similarity': 1.0},
#   {'id': 'Q1370',
#    'name': 'Virginia, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 23,
#    'popularity': 0.25,
#    'pos_score': 0.65,
#    'es_score': 0.956,
#    'ed_score': 0.57,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.53,
#    'cosine_similarity': 0.78},
#   {'id': 'Q771',
#    'name': 'Massachusetts, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 28,
#    'popularity': 0.25,
#    'pos_score': 0.66,
#    'es_score': 0.956,
#    'ed_score': 0.46,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.4,
#    'cosine_similarity': 0.78},
#   {'id': 'Q824',
#    'name': 'Oregon, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.24,
#    'pos_score': 0.67,
#    'es_score': 0.956,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.81},
#   {'id': 'Q1227',
#    'name': 'Nevada, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.25,
#    'pos_score': 0.68,
#    'es_score': 0.956,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.81},
#   {'id': 'Q4917',
#    'name': 'United States buck',
#    'description': 'currency of the United States of America',
#    'types': [{'id': 'Q756202', 'name': 'reserve currency'},
#     {'id': 'Q8142', 'name': 'currency'},
#     {'id': 'Q14083', 'name': 'dollar'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 18,
#    'popularity': 0.19,
#    'pos_score': 0.69,
#    'es_score': 0.956,
#    'ed_score': 0.72,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.8,
#    'cosine_similarity': 0.89},
#   {'id': 'Q1553',
#    'name': 'Nebraska, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 23,
#    'popularity': 0.23,
#    'pos_score': 0.7,
#    'es_score': 0.956,
#    'ed_score': 0.57,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.53,
#    'cosine_similarity': 0.81},
#   {'id': 'Q16557',
#    'name': 'Dallas, United States',
#    'description': 'county seat of Dallas County, Texas; ninth largest city in the United States by population',
#    'types': [{'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q1549591', 'name': 'big city'},
#     {'id': 'Q1637706', 'name': 'million city'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.19,
#    'pos_score': 0.73,
#    'es_score': 0.956,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.83},
#   {'id': 'Q16559',
#    'name': 'Austin, United States',
#    'description': 'capital of Texas, United States',
#    'types': [{'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q1549591', 'name': 'big city'},
#     {'id': 'Q21518270',
#      'name': 'state or insular area capital of the United States'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.17,
#    'pos_score': 0.74,
#    'es_score': 0.955,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.8},
#   {'id': 'Q48525',
#    'name': 'United States Executive',
#    'description': 'national government of the United States',
#    'types': [{'id': 'Q1006644', 'name': 'federal government'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 23,
#    'popularity': 0.06,
#    'pos_score': 0.75,
#    'es_score': 0.955,
#    'ed_score': 0.57,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.53,
#    'cosine_similarity': 0.88},
#   {'id': 'Q16555',
#    'name': 'Houston, United States',
#    'description': 'county seat of Harris County, Texas; fourth largest city in the United States by population',
#    'types': [{'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q1549591', 'name': 'big city'},
#     {'id': 'Q1637706', 'name': 'million city'},
#     {'id': 'Q62049', 'name': 'county seat'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.2,
#    'pos_score': 0.77,
#    'es_score': 0.955,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.81},
#   {'id': 'Q5092',
#    'name': 'Baltimore, United States',
#    'description': 'independent city in Maryland, United States',
#    'types': [{'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q1266818', 'name': 'independent city'},
#     {'id': 'Q1549591', 'name': 'big city'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 24,
#    'popularity': 0.16,
#    'pos_score': 0.78,
#    'es_score': 0.955,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.79},
#   {'id': 'Q330963',
#    'name': 'United States politics',
#    'description': 'overview of political matters in the United States of America',
#    'types': [],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.06,
#    'pos_score': 0.79,
#    'es_score': 0.955,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.9},
#   {'id': 'Q11220',
#    'name': 'United States navy',
#    'description': "maritime warfare branch of the United States' military",
#    'types': [{'id': 'Q4508', 'name': 'navy'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 18,
#    'popularity': 0.09,
#    'pos_score': 0.82,
#    'es_score': 0.955,
#    'ed_score': 0.72,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.8,
#    'cosine_similarity': 0.84},
#   {'id': 'Q16568',
#    'name': 'Jacksonville, United States',
#    'description': 'city in Florida, United States of America',
#    'types': [{'id': 'Q1093829', 'name': 'city of the United States'},
#     {'id': 'Q1549591', 'name': 'big city'},
#     {'id': 'Q3301053', 'name': 'consolidated city-county'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 27,
#    'popularity': 0.14,
#    'pos_score': 0.84,
#    'es_score': 0.955,
#    'ed_score': 0.48,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.42,
#    'cosine_similarity': 0.76},
#   {'id': 'Q1588',
#    'name': 'Louisiana, United States',
#    'description': 'state in the southern United States',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 24,
#    'popularity': 0.24,
#    'pos_score': 0.85,
#    'es_score': 0.955,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.76},
#   {'id': 'Q11299',
#    'name': 'Manhattan, United States',
#    'description': 'borough of New York City, New York, United States',
#    'types': [{'id': 'Q408804', 'name': 'borough of New York City'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 24,
#    'popularity': 0.14,
#    'pos_score': 0.86,
#    'es_score': 0.955,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.82},
#   {'id': 'Q1214',
#    'name': 'Wyoming, United States',
#    'description': 'least populous state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 22,
#    'popularity': 0.24,
#    'pos_score': 0.87,
#    'es_score': 0.955,
#    'ed_score': 0.59,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.57,
#    'cosine_similarity': 0.78},
#   {'id': 'Q782',
#    'name': 'Hawaii, United States',
#    'description': 'state of the United States of America, located on an archipelago in the Pacific Ocean',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.28,
#    'pos_score': 0.88,
#    'es_score': 0.955,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.82},
#   {'id': 'Q1439',
#    'name': 'Texas, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 20,
#    'popularity': 0.28,
#    'pos_score': 0.89,
#    'es_score': 0.955,
#    'ed_score': 0.65,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.67,
#    'cosine_similarity': 0.79},
#   {'id': 'Q11698',
#    'name': 'United States constitution',
#    'description': 'Supreme law of the United States of America',
#    'types': [{'id': 'Q7755', 'name': 'constitution'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 26,
#    'popularity': 0.13,
#    'pos_score': 0.9,
#    'es_score': 0.955,
#    'ed_score': 0.5,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.44,
#    'cosine_similarity': 0.86},
#   {'id': 'Q131110',
#    'name': 'United States History',
#    'description': 'occurrences and people in the USA throughout history',
#    'types': [{'id': 'Q11862829', 'name': 'academic discipline'},
#     {'id': 'Q4671286', 'name': 'academic major'},
#     {'id': 'Q17544377', 'name': 'history of a country or state'},
#     {'id': 'Q1047113', 'name': 'specialty'},
#     {'id': 'Q81517619', 'name': 'branch of history'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.11,
#    'pos_score': 0.91,
#    'es_score': 0.955,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.77},
#   {'id': 'Q797',
#    'name': 'Alaska, United States',
#    'description': 'state of the United States of America',
#    'types': [{'id': 'Q35657', 'name': 'U.S. state'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 21,
#    'popularity': 0.28,
#    'pos_score': 0.92,
#    'es_score': 0.955,
#    'ed_score': 0.62,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.62,
#    'cosine_similarity': 0.8},
#   {'id': 'Q5365167',
#    'name': 'Portal:The United States',
#    'description': 'Wikimedia portal',
#    'types': [{'id': 'Q4663903', 'name': 'Wikimedia portal'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 24,
#    'popularity': 0.08,
#    'pos_score': 0.93,
#    'es_score': 0.955,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.83},
#   {'id': 'Q11701',
#    'name': 'United States congresswoman',
#    'description': 'lower house of the United States Congress',
#    'types': [{'id': 'Q2145277', 'name': 'house of representatives'},
#     {'id': 'Q110315658', 'name': 'elected legislative house'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 27,
#    'popularity': 0.1,
#    'pos_score': 0.94,
#    'es_score': 0.955,
#    'ed_score': 0.48,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.42,
#    'cosine_similarity': 0.85},
#   {'id': 'Q11696',
#    'name': 'United states presidency',
#    'description': 'head of state and of government of the United States',
#    'types': [{'id': 'Q17279032', 'name': 'elective office'},
#     {'id': 'Q248577', 'name': 'President of the Republic'},
#     {'id': 'Q48352', 'name': 'head of state'},
#     {'id': 'Q2285706', 'name': 'head of government'},
#     {'id': 'Q380782', 'name': 'commander-in-chief'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 24,
#    'popularity': 0.14,
#    'pos_score': 0.95,
#    'es_score': 0.955,
#    'ed_score': 0.54,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.5,
#    'cosine_similarity': 0.86},
#   {'id': 'Q12612',
#    'name': 'West United States',
#    'description': 'region comprising the westernmost states of the United States',
#    'types': [{'id': 'Q82794', 'name': 'geographic region'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 18,
#    'popularity': 0.05,
#    'pos_score': 0.96,
#    'es_score': 0.955,
#    'ed_score': 0.72,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.8,
#    'cosine_similarity': 0.84},
#   {'id': 'Q83873577',
#    'name': 'Covid United States',
#    'description': 'ongoing coronavirus pandemic in the United States',
#    'types': [{'id': 'Q3241045', 'name': 'disease outbreak'},
#     {'id': 'Q216227', 'name': 'state of emergency'}],
#    'ambiguity_mention': 0.747,
#    'corrects_tokens': 1.0,
#    'ntoken_mention': 2,
#    'ntoken_entity': 3,
#    'length_mention': 13,
#    'length_entity': 19,
#    'popularity': 0.06,
#    'pos_score': 1.0,
#    'es_score': 0.955,
#    'ed_score': 0.68,
#    'jaccard_score': 0.67,
#    'jaccardNgram_score': 0.73,
#    'cosine_similarity': 0.85}]}

# %%
column_metadata

# %%
header_results[0]["winningCandidates"]

# %%
lamapi_wrapper.literal_recognizer(["ROME", "usA", "belgium"])

# %%
compute_datatype(rows, lamapi_wrapper)

# %%
cpa._cpa

# %%
cta._cta
# Out:
# {'0': {'Q33999': 0.667,
#   'Q488205': 0.667,
#   'Q639669': 0.333,
#   'Q2405480': 0.333,
#   'Q177220': 0.667,
#   'Q36834': 0.333,
#   'Q10798782': 0.667,
#   'Q10800557': 0.667,
#   'Q9648008': 0.333,
#   'Q55960555': 0.667,
#   'Q5': 1.0,
#   'Q486748': 0.333,
#   'Q855091': 0.333,
#   'Q1327329': 0.333,
#   'Q1028181': 0.333,
#   'Q482980': 0.333,
#   'Q3282637': 0.333,
#   'Q2259451': 0.333},
#  '1': {'Q13218391': 0.333,
#   'Q62049': 0.333,
#   'Q1093829': 0.667,
#   'Q1549591': 1.0,
#   'Q50330360': 0.333,
#   'Q515': 1.0,
#   'Q1388464': 0.333,
#   'Q21507383': 0.333,
#   'Q208511': 0.333,
#   'Q2264924': 0.333,
#   'Q51929311': 0.333,
#   'Q15063611': 0.333,
#   'Q1637706': 0.333},
#  '2': {'Q3624078': 1.0,
#   'Q1520223': 0.667,
#   'Q5255892': 0.667,
#   'Q512187': 0.667,
#   'Q1489259': 0.667,
#   'Q6256': 1.0,
#   'Q99541706': 0.667,
#   'Q223832': 0.333,
#   'Q202686': 0.333,
#   'Q43702': 0.333}}

# %%
results_cea

# %%
rows

# %%
weights = {"ed": 8, "jaccard": 7, "jaccardNgram": 5, "p_subj_ne": 5, "p_subj_lit": 7, "p_obj_ne": 4, "desc":2, "descNgram": 3} 
candidates = results_cea[0]["winningCandidates"][0]
for candidate in candidates:
    score = 0
    for feature in weights:     
        score += candidate["features"][feature] * weights[feature]
    print(candidate, score)

# %%
results_cea[0]["winningCandidates"][1]

# %%
results_cea[2]

# %%
candidates[3]['candidates'][0]

# %%
import pandas as pd
from tqdm import tqdm
def get_cea_ann(cea_gt_path):
    gt_files = pd.read_csv(cea_gt_path)
    target = {}
    for row in tqdm(gt_files.itertuples(), total=len(gt_files)):
        id_table, id_row, id_col, gt = (row[i] for i in range(1, 5))
        key = f"{id_table} {id_row} {id_col}"
        target[key] = gt
    return target 

cea_target_path = '../data/2T/DataSets/ToughTablesR2-WD/Valid/gt/cea_gt.csv'
cpa_target_path = './data/HardTableR2/targets/HardTable_CPA_WD_Round2_Targets.csv'
cta_target_path = './data/2T/DataSets/ToughTablesR2-WD/Valid/gt/cta_gt.csv'

cea_gt = get_cea_ann(cea_target_path)
my_cea = { }
for row in results_cea:
    id_row = row["row"]
    id_table = row["tableName"]
    for id_col in row["cea"]:
        if row["winningCandidates"][int(id_col)][0]["score"] > 1 or True:
            my_cea[f"{id_table} {id_row} {id_col}"] = row["cea"][id_col]
sum([1 for key in my_cea if my_cea[key] in cea_gt.get(key, [])]) / len(my_cea)

# %%
len(my_cea)

# %%
[(key, my_cea[key], cea_gt.get(key)) for key in my_cea if my_cea[key] not in cea_gt.get(key, [])]

# %%
pip install nltk

# %%
import os
import time
import traceback

from elasticsearch import Elasticsearch
from mongodb_conn import get_collection
from body import body
import copy

ELASTIC_ENDPOINT = os.environ['ELASTIC_ENDPOINT']
ELASTIC_ENDPOINT_PORT = os.environ['ELASTIC_ENDPOINT_PORT']
ELASTIC_INDEX_NAME = os.environ['ELASTIC_INDEX_NAME']
ELASTICSEARCH_USERNAME = os.environ['ELASTICSEARCH_USERNAME']
ELASTICSEARCH_PASSWORD = os.environ['ELASTICSEARCH_PASSWORD']



es = Elasticsearch(hosts=f'http://{ELASTIC_ENDPOINT}:{ELASTIC_ENDPOINT_PORT}', request_timeout=300, max_retries=10, 
                    retry_on_timeout=True, http_auth=(ELASTICSEARCH_USERNAME, ELASTICSEARCH_PASSWORD))
es.info()

# %%
f'http://{ELASTIC_ENDPOINT}:{ELASTIC_ENDPOINT_PORT}', ELASTICSEARCH_USERNAME, ELASTICSEARCH_PASSWORD

# %%
import os
import time
import traceback

from elasticsearch import Elasticsearch
from mongodb_conn import get_collection
from body import body
import copy
import requests

headers = {
    'accept': 'application/json',
    # Already added when you pass json= but not when you pass data=
    # 'Content-Type': 'application/json',
}

params = {
    'token': 'ee4ba0c4f8db0eb3580cb3b7b5536c54',
}
ELASTIC_ENDPOINT = os.environ['ELASTIC_ENDPOINT']
ELASTIC_ENDPOINT_PORT = os.environ['ELASTIC_ENDPOINT_PORT']


(cells_c, candidate_c, log_c, missing_c) = [get_collection(name) for name in ['cell', 'candidate', 'log', 'missing_c']]


def get_query(cell, type=None):
    if type is None:
        query = copy.deepcopy(body['token+ngrams'])
    else:
        query = copy.deepcopy(body['token+ngrams+type'])
        query['bool']['should'][2]['match']['type']['query'] = type
    query['bool']['should'][0]['match']['name']['query'] = cell
    query['bool']['should'][1]['match']['name.ngrams']['query'] = cell    
    query['bool']['must'][0]['range']['ntoken']['gte'] = len(cell.split(' ')) - 3
    query['bool']['must'][0]['range']['ntoken']['lte'] = len(cell.split(' ')) + 3    
    return query

query = get_query('paris')
candidates = requests.post(f'http://{ELASTIC_ENDPOINT}:{ELASTIC_ENDPOINT_PORT}/lookupES', 
                                        params=params, headers=headers, 
                                        json={'json': {"query": query}})

# %%
candidates.json()

# %%
from keras.models import load_model



neural2_path = "./ml_models/neural_network2.h5"


model = load_model(neural2_path)
# Out:
# 2023-05-30 09:03:18.308273: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-30 09:03:18.689361: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-30 09:03:18.689381: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-30 09:03:20.036941: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-30 09:03:20.037101: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-30 09:03:20.037113: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-05-30 09:03:21.728055: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-05-30 09:03:21.728294: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-30 09:03:21.728322: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (9d88231cdc7a): /proc/driver/nvidia/version does not exist
# 2023-05-30 09:03:21.729097: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
featues = { 
    "ntoken" : 3, 
    "popularity" : 100, 
    "pos_score" : 0.02, 
    "es_score" : 52.99, 
    "es_diff_score" : 0.072337, 
    "ed" : 0.48, 
    "jaccard" : 0.5, 
    "jaccardNgram" : 0.72, 
    "cosine_similarity" : 0.65, 
    "p_subj_ne" : 0, 
    "p_subj_lit" : 0, 
    "p_obj_ne" : 0, 
    "desc" : 0.125, 
    "descNgram" : 0.277, 
    "cpa" : 0.0, 
    "cpaMax" : 0, 
    "cta" : 1.0, 
    "ctaMax" : 1.0, 
    "cea" : 1.0, 
    "diff" : 0.0 
}

# %%
# Out:
# [[3,
#   998617,
#   0.02,
#   52.99,
#   0.072337,
#   0.48,
#   0.5,
#   0.72,
#   0.65,
#   0,
#   0,
#   0,
#   0.125,
#   0.277,
#   0.0,
#   0,
#   1.0,
#   1.0,
#   1.0,
#   0.0]]

# %%
model.predict([list(featues.values())])
# Out:
# 1/1 [==============================] - 0s 87ms/step
# array([[0.3178707, 0.6821293]], dtype=float32)
